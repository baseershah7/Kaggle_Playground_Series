# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/optimal-fertilizers-features/training_data.csv
# /kaggle/input/optimal-fertilizers-features/test_data.csv
# /kaggle/input/playground-series-s5e6/sample_submission.csv
# /kaggle/input/playground-series-s5e6/train.csv
# /kaggle/input/playground-series-s5e6/test.csv
# /kaggle/input/fertilizer-prediction/Fertilizer Prediction.csv

# %%
# !pip install autofeat

# %%
train = pd.read_csv('/kaggle/input/playground-series-s5e6/train.csv')
test = pd.read_csv('/kaggle/input/playground-series-s5e6/test.csv')
X_new = pd.read_csv('/kaggle/input/optimal-fertilizers-features/training_data.csv')
test_new = pd.read_csv('/kaggle/input/optimal-fertilizers-features/test_data.csv')
train_org = pd.read_csv('/kaggle/input/fertilizer-prediction/Fertilizer Prediction.csv')
sample_sub = pd.read_csv('/kaggle/input/playground-series-s5e6/sample_submission.csv')

# %%
train_new = pd.concat([train.drop(columns='id'), train_org])

# %%
train_new.head(3)
# Out:
#    Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0           37        70        36    Clayey  Sugarcane        36          4
# 1           27        69        65     Sandy    Millets        30          6
# 2           29        63        32     Sandy    Millets        24         12
#
#    Phosphorous Fertilizer Name
# 0            5           28-28
# 1           18           28-28
# 2           16        17-17-17

# %%
seed=1
folds=10

np.random.seed(seed)
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.base import clone
from sklearn.metrics import make_scorer

def mapk_score(y_true, y_score, k=3):
    sorted_predictions = np.argsort(y_score, axis=1)[:, -3:][:, ::-1]
    map_at_3 = 0
    for i in range(3):
        map_at_3 += (sorted_predictions[:, i] == y_true).sum() / (i+1)

    return map_at_3 / len(y_score)

def cv_score(X, y, model_dict, folds=folds, seed=seed, k=3):
    skf = StratifiedKFold(random_state=seed, n_splits=folds, shuffle=True)
    results = {}
    mapk_scorer = make_scorer(
        mapk_score, 
        needs_proba=True,
        greater_is_better=True,
        k=k
    )
    for name, model in model_dict.items():
        print(f'current model being processed :{name}')
        map_scores = []
        scores = []
        for i, (train_index, valid_index) in enumerate(skf.split(X, y), 1):
            X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
            y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
            # clf = clone(model)
            model.fit(X_train, y_train)
            # probas = model.predict_proba(X_valid)

            # score = mapk_score(y_valid, probas, k=k)
            score = mapk_scorer(model, X_valid, y_valid)
            print(f'Score for {name} on fold {i} is {score}')
            scores.append(score)
        
        results[name] = np.mean(scores)
        print(f'Mean score for {name} is {results[name]}')

    return results

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

class IntenseTargetEncoder(BaseEstimator, TransformerMixin):
    """
    Comprehensive Target Encoder for multiclass classification with multiple encoding strategies
    """
    
    def __init__(self, categorical_cols=None, smoothing=1.0, min_samples_leaf=1, 
                 noise_level=0.01, cv_folds=5, random_state=42, 
                 encoding_methods=['mean', 'count', 'std', 'median']):
        """
        Parameters:
        -----------
        categorical_cols : list, columns to encode
        smoothing : float, smoothing parameter for regularization
        min_samples_leaf : int, minimum samples to consider for encoding
        noise_level : float, noise to add to prevent overfitting
        cv_folds : int, cross-validation folds for out-of-fold encoding
        encoding_methods : list, types of encodings to apply
        """
        self.categorical_cols = categorical_cols
        self.smoothing = smoothing
        self.min_samples_leaf = min_samples_leaf
        self.noise_level = noise_level
        self.cv_folds = cv_folds
        self.random_state = random_state
        self.encoding_methods = encoding_methods
        self.label_encoder = LabelEncoder()
        self.target_encodings = {}
        self.global_stats = {}
        
    def _get_target_stats(self, df, col, target_values):
        """Calculate various statistics for target encoding"""
        stats = {}
        # Create a temporary dataframe with the column and target values
        temp_df = pd.DataFrame({
            'category': df[col],
            'target': target_values
        })
        grouped = temp_df.groupby('category')['target']
        
        if 'mean' in self.encoding_methods:
            stats['mean'] = grouped.mean()
        if 'count' in self.encoding_methods:
            stats['count'] = grouped.count()
        if 'std' in self.encoding_methods:
            stats['std'] = grouped.std().fillna(0)
        if 'median' in self.encoding_methods:
            stats['median'] = grouped.median()
        if 'min' in self.encoding_methods:
            stats['min'] = grouped.min()
        if 'max' in self.encoding_methods:
            stats['max'] = grouped.max()
        if 'nunique' in self.encoding_methods:
            stats['nunique'] = grouped.nunique()
            
        return stats
    
    def _smooth_encoding(self, category_stats, global_mean, count):
        """Apply smoothing to prevent overfitting"""
        return (category_stats * count + global_mean * self.smoothing) / (count + self.smoothing)
    
    def _add_noise(self, encoded_values):
        """Add small amount of noise to encoded values"""
        if self.noise_level > 0:
            noise = np.random.normal(0, self.noise_level, len(encoded_values))
            return encoded_values + noise
        return encoded_values
    
    def _create_interaction_features(self, df, col, target_values):
        """Create interaction features between categorical variables"""
        interactions = {}
        other_cats = [c for c in self.categorical_cols if c != col and c in df.columns]
        
        for other_col in other_cats[:2]:  # Limit to 2 interactions to prevent explosion
            interaction_col = f"{col}_{other_col}"
            temp_df = df.copy()
            temp_df[interaction_col] = temp_df[col].astype(str) + "_" + temp_df[other_col].astype(str)
            interactions[interaction_col] = self._get_target_stats(temp_df, interaction_col, target_values)
        
        return interactions
    
    def fit(self, X, y):
        """Fit the target encoder"""
        df = X.copy()
        
        # Encode target variable
        y_encoded = self.label_encoder.fit_transform(y)
        
        # Determine categorical columns if not specified
        if self.categorical_cols is None:
            self.categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
        
        # Calculate global statistics
        for method in self.encoding_methods:
            if method == 'mean':
                self.global_stats['mean'] = y_encoded.mean()
            elif method == 'std':
                self.global_stats['std'] = y_encoded.std()
            elif method == 'median':
                self.global_stats['median'] = np.median(y_encoded)
            elif method == 'count':
                self.global_stats['count'] = len(y_encoded)
        
        # Cross-validation target encoding
        skf = StratifiedKFold(n_splits=self.cv_folds, shuffle=True, random_state=self.random_state)
        
        for col in self.categorical_cols:
            print(f"Encoding column: {col}")
            self.target_encodings[col] = {}
            
            # Full dataset encoding for transform
            col_stats = self._get_target_stats(df, col, y_encoded)
            
            for method in self.encoding_methods:
                if method in col_stats:
                    # Apply smoothing
                    counts = col_stats['count'] if 'count' in col_stats else df.groupby(col).size()
                    smoothed_stats = {}
                    
                    for category in col_stats[method].index:
                        category_stat = col_stats[method][category]
                        category_count = counts[category] if category in counts else 1
                        
                        if category_count >= self.min_samples_leaf:
                            if method == 'mean':
                                smoothed_stats[category] = self._smooth_encoding(
                                    category_stat, self.global_stats['mean'], category_count
                                )
                            else:
                                smoothed_stats[category] = category_stat
                        else:
                            # Use global statistic for rare categories
                            smoothed_stats[category] = self.global_stats.get(method, category_stat)
                    
                    self.target_encodings[col][method] = smoothed_stats
            
            # Create interaction features
            interactions = self._create_interaction_features(df, col, y_encoded)
            for interaction_name, interaction_stats in interactions.items():
                self.target_encodings[interaction_name] = {}
                for method in self.encoding_methods:
                    if method in interaction_stats:
                        self.target_encodings[interaction_name][method] = dict(interaction_stats[method])
        
        return self
    
    def transform(self, X):
        """Transform the data using fitted encodings"""
        df = X.copy()
        
        # Convert categorical columns to object type to avoid categorical constraints
        for col in df.columns:
            if hasattr(df[col], 'cat'):  # Check if it's categorical
                df[col] = df[col].astype(str)
        
        for col in self.categorical_cols:
            if col not in df.columns:
                continue
                
            for method in self.encoding_methods:
                if method in self.target_encodings[col]:
                    new_col_name = f"{col}_target_{method}"
                    encoding_dict = self.target_encodings[col][method]
                    
                    # Map values, use global mean for unseen categories
                    default_value = self.global_stats.get(method, 0)
                    encoded_series = df[col].astype(str).map(encoding_dict)
                    df[new_col_name] = encoded_series.fillna(default_value).astype(float)
                    
                    # Add noise to prevent overfitting
                    df[new_col_name] = self._add_noise(df[new_col_name])
        
        # Handle interaction features
        other_cats = [c for c in self.categorical_cols if c in df.columns]
        for i, col1 in enumerate(other_cats):
            for col2 in other_cats[i+1:i+3]:  # Limit interactions
                interaction_name = f"{col1}_{col2}"
                if interaction_name in self.target_encodings:
                    df[interaction_name] = df[col1].astype(str) + "_" + df[col2].astype(str)
                    
                    for method in self.encoding_methods:
                        if method in self.target_encodings[interaction_name]:
                            new_col_name = f"{interaction_name}_target_{method}"
                            encoding_dict = self.target_encodings[interaction_name][method]
                            default_value = self.global_stats.get(method, 0)
                            encoded_series = df[interaction_name].astype(str).map(encoding_dict)
                            df[new_col_name] = encoded_series.fillna(default_value).astype(float)
                            df[new_col_name] = self._add_noise(df[new_col_name])
                    
                    # Drop the interaction column itself
                    df.drop(interaction_name, axis=1, inplace=True)
        
        return df
    
    def fit_transform(self, X, y):
        """Fit and transform in one step with proper CV to prevent overfitting"""
        df = X.copy()
        
        # Convert categorical columns to object type to avoid categorical constraints
        for col in df.columns:
            if hasattr(df[col], 'cat'):  # Check if it's categorical
                df[col] = df[col].astype(str)
        
        y_encoded = self.label_encoder.fit_transform(y)
        
        # Determine categorical columns
        if self.categorical_cols is None:
            self.categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
        
        # Cross-validation encoding to prevent overfitting
        skf = StratifiedKFold(n_splits=self.cv_folds, shuffle=True, random_state=self.random_state)
        
        for col in self.categorical_cols:
            print(f"CV Encoding column: {col}")
            
            for method in self.encoding_methods:
                df[f"{col}_target_{method}"] = 0.0
        
        # Out-of-fold encoding
        for fold, (train_idx, val_idx) in enumerate(skf.split(df, y_encoded)):
            train_df = df.iloc[train_idx].copy()
            
            for col in self.categorical_cols:
                col_stats = self._get_target_stats(train_df, col, y_encoded[train_idx])
                
                for method in self.encoding_methods:
                    if method in col_stats:
                        encoding_dict = dict(col_stats[method])
                        default_value = y_encoded[train_idx].mean() if method == 'mean' else 0
                        
                        # Apply to validation set
                        encoded_values = df.iloc[val_idx][col].astype(str).map(encoding_dict).fillna(default_value).astype(float)
                        df.iloc[val_idx, df.columns.get_loc(f"{col}_target_{method}")] = encoded_values
        
        # Fit on full data for future transforms
        self.fit(X, y)
        
        return df


def create_target_encoded_features(X_train, y_train, X_test=None, 
                                 categorical_cols=None, cv_folds=5, random_state=42):
    """
    Convenience function to create target encoded features
    """
    encoder = IntenseTargetEncoder(
        categorical_cols=categorical_cols,
        smoothing=1.0,
        min_samples_leaf=1,
        noise_level=0.01,
        cv_folds=cv_folds,
        random_state=random_state,
        encoding_methods=['mean', 'count', 'std', 'median', 'nunique']
    )
    
    # Fit and transform training data with CV
    X_train_encoded = encoder.fit_transform(X_train, y_train)
    
    # Transform test data if provided
    if X_test is not None:
        X_test_encoded = encoder.transform(X_test)
        return X_train_encoded, X_test_encoded, encoder
    
    return X_train_encoded, encoder


# Analysis and visualization functions
def analyze_target_encoding_quality(X_original, X_encoded, y, categorical_cols, encoder=None):
    """
    Analyze the quality and effectiveness of target encoding
    """
    print("="*80)
    print("TARGET ENCODING QUALITY ANALYSIS")
    print("="*80)
    
    # Basic info
    print(f"Original dataset shape: {X_original.shape}")
    print(f"Encoded dataset shape: {X_encoded.shape}")
    print(f"New features added: {X_encoded.shape[1] - X_original.shape[1]}")
    print()
    
    # Show new columns
    original_cols = set(X_original.columns)
    encoded_cols = set(X_encoded.columns)
    new_cols = encoded_cols - original_cols
    
    print("NEW ENCODED FEATURES:")
    for col in sorted(new_cols):
        print(f"  - {col}")
    print()
    
    # Analyze each categorical column's encoding
    for cat_col in categorical_cols:
        if cat_col not in X_original.columns:
            continue
            
        print(f"ANALYSIS FOR '{cat_col}':")
        print("-" * 50)
        
        # Original column info
        unique_vals = X_original[cat_col].nunique()
        print(f"Unique categories: {unique_vals}")
        print(f"Value counts:")
        print(X_original[cat_col].value_counts().head())
        print()
        
        # Show encoded features for this column
        encoded_features = [col for col in new_cols if col.startswith(f"{cat_col}_target_")]
        
        for enc_col in encoded_features:
            if enc_col in X_encoded.columns:
                enc_values = X_encoded[enc_col]
                print(f"  {enc_col}:")
                print(f"    Range: [{enc_values.min():.4f}, {enc_values.max():.4f}]")
                print(f"    Mean: {enc_values.mean():.4f}")
                print(f"    Std: {enc_values.std():.4f}")
                print(f"    Unique values: {enc_values.nunique()}")
        print()
    
    # Show correlation with target (if possible)
    if hasattr(encoder, 'label_encoder') and encoder.label_encoder is not None:
        try:
            from sklearn.preprocessing import LabelEncoder
            le_temp = LabelEncoder()
            y_numeric = le_temp.fit_transform(y)
            
            print("CORRELATION WITH TARGET (top 10 features):")
            print("-" * 50)
            correlations = []
            for col in new_cols:
                if col in X_encoded.columns:
                    corr = np.corrcoef(X_encoded[col], y_numeric)[0, 1]
                    if not np.isnan(corr):
                        correlations.append((col, abs(corr)))
            
            correlations.sort(key=lambda x: x[1], reverse=True)
            for col, corr in correlations[:10]:
                print(f"  {col}: {corr:.4f}")
        except:
            print("Could not calculate correlations with target")
    
    print("="*80)
    return X_encoded

def compare_categorical_vs_encoded(X_original, X_encoded, categorical_col, target_col_prefix):
    """
    Compare original categorical values with their encoded counterparts
    """
    if categorical_col not in X_original.columns:
        print(f"Column {categorical_col} not found in original data")
        return
    
    encoded_cols = [col for col in X_encoded.columns if col.startswith(f"{categorical_col}_target_")]
    
    if not encoded_cols:
        print(f"No encoded columns found for {categorical_col}")
        return
    
    print(f"COMPARISON FOR '{categorical_col}':")
    print("="*60)
    
    # Create comparison dataframe
    comparison_df = X_original[[categorical_col]].copy()
    for enc_col in encoded_cols:
        comparison_df[enc_col] = X_encoded[enc_col]
    
    # Group by categorical value and show encoding stats
    grouped = comparison_df.groupby(categorical_col)
    
    for category, group in grouped:
        print(f"\nCategory: '{category}' (n={len(group)})")
        print("-" * 30)
        for enc_col in encoded_cols:
            values = group[enc_col]
            print(f"  {enc_col}:")
            print(f"    Mean: {values.mean():.4f}")
            print(f"    Std: {values.std():.4f}")
            print(f"    Range: [{values.min():.4f}, {values.max():.4f}]")
    
    return comparison_df

def visualize_encoding_distribution(X_encoded, categorical_cols, save_plots=False):
    """
    Create visualizations of the encoded features
    """
    try:
        import matplotlib.pyplot as plt
        import seaborn as sns
        
        # Set style
        plt.style.use('default')
        sns.set_palette("husl")
        
        for cat_col in categorical_cols:
            encoded_features = [col for col in X_encoded.columns if col.startswith(f"{cat_col}_target_")]
            
            if not encoded_features:
                continue
                
            n_features = len(encoded_features)
            fig, axes = plt.subplots(2, (n_features + 1) // 2, figsize=(15, 8))
            fig.suptitle(f'Distribution of Encoded Features for {cat_col}', fontsize=16)
            
            if n_features == 1:
                axes = [axes]
            elif n_features <= 2:
                axes = axes.flatten()
            else:
                axes = axes.flatten()
            
            for i, enc_col in enumerate(encoded_features):
                if i < len(axes):
                    axes[i].hist(X_encoded[enc_col], bins=30, alpha=0.7, edgecolor='black')
                    axes[i].set_title(enc_col.replace(f"{cat_col}_target_", "").upper())
                    axes[i].set_xlabel('Encoded Value')
                    axes[i].set_ylabel('Frequency')
            
            # Hide empty subplots
            for j in range(len(encoded_features), len(axes)):
                axes[j].set_visible(False)
            
            plt.tight_layout()
            
            if save_plots:
                plt.savefig(f'{cat_col}_encoding_distribution.png', dpi=300, bbox_inches='tight')
            
            plt.show()
            
    except ImportError:
        print("Matplotlib/Seaborn not available for plotting")

# Updated convenience function with analysis
def create_target_encoded_features_with_analysis(X_train, y_train, X_test=None, 
                                               categorical_cols=None, cv_folds=5, 
                                               random_state=seed, analyze=True):
    """
    Convenience function to create target encoded features with quality analysis
    """
    print("Creating target encoded features...")
    
    encoder = IntenseTargetEncoder(
        categorical_cols=categorical_cols,
        smoothing=1.0,
        min_samples_leaf=1,
        noise_level=0.01,
        cv_folds=cv_folds,
        random_state=random_state,
        encoding_methods=['mean', 'count', 'std', 'median', 'nunique']
    )
    
    # Fit and transform training data with CV
    X_train_encoded = encoder.fit_transform(X_train, y_train)
    
    if analyze:
        # Analyze encoding quality
        X_train_encoded = analyze_target_encoding_quality(
            X_train, X_train_encoded, y_train, 
            encoder.categorical_cols, encoder
        )
    
    # Transform test data if provided
    if X_test is not None:
        X_test_encoded = encoder.transform(X_test)
        return X_train_encoded, X_test_encoded, encoder
    
    return X_train_encoded, encoder
    """
    Cross-validation with proper target encoding to prevent data leakage
    """
    from sklearn.model_selection import StratifiedKFold
    from sklearn.metrics import make_scorer
    
    skf = StratifiedKFold(random_state=seed, n_splits=folds, shuffle=True)
    results = {}
    
    # Assuming you have mapk_score function defined
    mapk_scorer = make_scorer(
        mapk_score, 
        needs_proba=True,
        greater_is_better=True,
        k=k
    )
    
    for name, model in model_dict.items():
        print(f'Current model being processed: {name}')
        scores = []
        
        for i, (train_index, valid_index) in enumerate(skf.split(X, y), 1):
            X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
            y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
            
            # Apply target encoding within each fold
            encoder = IntenseTargetEncoder(
                categorical_cols=categorical_cols,
                cv_folds=3,  # Nested CV for encoding
                random_state=seed
            )
            
            # Fit encoder on training data and transform both sets
            encoder.fit(X_train, y_train)
            X_train_encoded = encoder.transform(X_train)
            X_valid_encoded = encoder.transform(X_valid)
            
            # Train model
            model.fit(X_train_encoded, y_train)
            
            # Score model
            score = mapk_scorer(model, X_valid_encoded, y_valid)
            print(f'Score for {name} on fold {i} is {score}')
            scores.append(score)
        
        results[name] = np.mean(scores)
        print(f'Mean score for {name} is {results[name]}')
    
    return results


# Example usage for your fertilizer dataset
def apply_target_encoding_to_fertilizer_data(df, target_col='Fertilizer Name'):
    """
    Apply target encoding specifically to fertilizer dataset
    """
    # Identify categorical columns
    categorical_cols = ['Soil Type', 'Crop Type']  # Add other categorical columns as needed
    
    # Separate features and target
    X = df.drop(target_col, axis=1)
    y = df[target_col]
    
    # Apply target encoding
    X_encoded, encoder = create_target_encoded_features(
        X, y, 
        categorical_cols=categorical_cols,
        cv_folds=5,
        random_state=42
    )
    
    print("Original features:", X.columns.tolist())
    print("Encoded features:", X_encoded.columns.tolist())
    print("New features added:", [col for col in X_encoded.columns if col not in X.columns])
    
    return X_encoded, y, encoder

# %%
class_mapping = {
    '14-35-14':0,
    '10-26-26':1,
    '17-17-17':2,
    '28-28':3,
    '20-20':4,
    'DAP':5,
    'Urea':6
}
rev_class_mapping = {
    0:'14-35-14',
    1:'10-26-26',
    2:'17-17-17',
    3:'28-28',
    4:'20-20',
    5:'DAP',
    6:'Urea'
}

X = train.drop(columns=['id', 'Fertilizer Name'])
X_full = train_new.drop(columns=['Fertilizer Name'])
y = train['Fertilizer Name']
y_full = train_new['Fertilizer Name']
y_full = y_full.map(class_mapping)
y = y.map(class_mapping)

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

le = OrdinalEncoder()
le_2 = OrdinalEncoder()
obj_dtypes = X.select_dtypes(include=['object', 'category']).columns
X[obj_dtypes] = X[obj_dtypes].astype('category')
X_full[obj_dtypes] = X_full[obj_dtypes].astype('category')
test[obj_dtypes] = test[obj_dtypes].astype('category')
X[obj_dtypes] = le.fit_transform(X[obj_dtypes])
X_full[obj_dtypes] = le_2.fit_transform(X_full[obj_dtypes])
# encoded_df = pd.DataFrame(encoded_features, 
#                          columns=le.get_feature_names_out(obj_dtypes),
#                          index=X.index)
# X = pd.concat([X, encoded_df], axis=1)
# X.drop(columns=obj_dtypes, inplace=True)

# %%
le_2.categories_
# Out:
# [array(['Black', 'Clayey', 'Loamy', 'Red', 'Sandy'], dtype=object),
#  array(['Barley', 'Cotton', 'Ground Nuts', 'Maize', 'Millets', 'Oil seeds',
#         'Paddy', 'Pulses', 'Sugarcane', 'Tobacco', 'Wheat'], dtype=object)]

# %%
test[obj_dtypes] = le_2.transform(test[obj_dtypes])

# %%
# from autofeat import AutoFeatRegressor

# af = AutoFeatRegressor(feateng_steps=2, verbose=1, n_jobs=1)
# X_full = af.fit_transform(X_full, y_full)
# test_new = af.transform(test.drop(columns='id'))

# %%
# from sklearn.preprocessing import OrdinalEncoder

# def artificial_features(df):
#     df = df.copy()
    
#     # Nutrient Ratios
#     df['N_P_ratio'] = df['Nitrogen'] / df['Phosphorous'].replace(0,1)
#     df['P_K_ratio'] = df['Phosphorous'] / df['Potassium'].replace(0,1)
#     df['N_K_ratio'] = df['Nitrogen'] / df['Potassium'].replace(0,1)
#     df['NPK_sum'] = df['Nitrogen'] + df['Phosphorous'] + df['Potassium']
#     df['Nitrogen_deficient'] = (df['Nitrogen'] < 20).astype(int)
#     df['Phosphorus_deficient'] = (df['Phosphorous'] < 15).astype(int)
#     df['Potassium_deficient'] = (df['Potassium'] < 10).astype(int)
    
#     # 3. Polynomial Terms
#     df['Temp_squared'] = df['Temparature'] ** 2
#     df['Humidity_squared'] = df['Humidity'] ** 2
#     df['Moisture_squared'] = df['Moisture'] ** 2
    
#     # 4. Interaction Terms
#     df['Temp_Humidity'] = df['Temparature'] * df['Humidity']
#     df['Temp_Moisture'] = df['Temparature'] * df['Moisture']
#     df['Humidity_Moisture'] = df['Humidity'] * df['Moisture']
#     df['Temp_Humidity_Moisture'] = df['Temparature'] * df['Humidity'] * df['Moisture']
#     df['N_Humidity'] = df['Nitrogen'] * df['Humidity']
#     df['P_Moisture'] = df['Phosphorous'] * df['Moisture']
#     df['K_Temp'] = df['Potassium'] * df['Temparature']
    
#     # 5. Binned Features
#     df['Temp_bin'] = pd.cut(df['Temparature'], bins=5, labels=[0, 1, 2, 3, 4])
#     df['Humidity_bin'] = pd.cut(df['Humidity'], bins=5, labels=[0, 1, 2, 3, 4])
#     df['Moisture_bin'] = pd.cut(df['Moisture'], bins=5, labels=[0, 1, 2, 3, 4])
    
#     # 6. Aggregations by Crop Type
#     crop_stats = df.groupby('Crop Type')[['Nitrogen', 'Phosphorous', 'Potassium']].agg(['mean', 'median', 'std'])
#     crop_stats.columns = ['_'.join(col).strip() for col in crop_stats.columns]
#     df = df.merge(crop_stats, on='Crop Type', how='left')
    
#     # 7. Aggregations by Soil Type
#     soil_stats = df.groupby('Soil Type')[['Moisture', 'Temparature']].agg(['mean', 'median', 'std'])
#     soil_stats.columns = ['_'.join(col).strip() for col in soil_stats.columns]
#     df = df.merge(soil_stats, on='Soil Type', how='left')
    
#     # 8. Soil × Crop Interaction Features (Modified to use Ordinal Encoder)
#     # interaction = df[['Soil Type', 'Crop Type']].astype(str).agg('_'.join, axis=1).to_frame(name='Soil_Crop')
#     # encoder = OrdinalEncoder()
#     # encoded = encoder.fit_transform(interaction)
#     # df['Soil_Crop_encoded'] = encoded.flatten()
    
#     # 9. Derived Indices
#     df['THI'] = (1.8 * df['Temparature'] + 32) - ((100 - df['Humidity']) / 10 * 1.8)  # Temperature-Humidity Index
#     df['NPK_Balance'] = abs(df['N_P_ratio'] - 1) + abs(df['P_K_ratio'] - 1) + abs(df['N_K_ratio'] - 1)  # Nutrient Balance Score
    
#     return df.copy()

# X_full = artificial_features(X_full)
# test_new = artificial_features(test_new)

# %%
# interaction = X_new[['Soil Type', 'Crop Type']].astype(str).agg('_'.join, axis=1).to_frame(name='Soil_Crop')
# interaction_test = test_new[['Soil Type', 'Crop Type']].astype(str).agg('_'.join, axis=1).to_frame(name='Soil_Crop')

# le_2 = OrdinalEncoder()
# train_encoded = le_2.fit_transform(interaction)
# test_encoded = le_2.transform(interaction_test)

# X_new['Soil_Crop_encoded'] = train_encoded.flatten()
# test_new['Soil_Crop_encoded'] = test_encoded.flatten()

# %%
# X_full.to_csv('training_data.csv',index=False)
# test_new.to_csv('test_data.csv', index=False)

# %%
cols = ['Temparature', 'Humidity', 'Moisture', 'Nitrogen', 'Potassium',
       'Phosphorous', 'Moisture*Nitrogen**3', 'SoilType**2/Nitrogen',
       'Nitrogen**3/Moisture', 'CropType*Nitrogen**3', 'CropType**2/Moisture',
       'CropType**2/Nitrogen', 'Moisture**3*SoilType', 'CropType**3*Moisture',
       'Phosphorous*Potassium', 'Potassium**3/Nitrogen',
       'CropType*Potassium**2', 'CropType*exp(SoilType)',
       'Nitrogen*sqrt(SoilType)', 'CropType**2*Moisture**3',
       'sqrt(CropType)/Nitrogen', 'Potassium*exp(SoilType)',
       'Humidity**3*SoilType**3', 'CropType*Phosphorous**3',
       'Phosphorous*exp(SoilType)', 'SoilType**3*Temparature**2',
       'sqrt(Phosphorous)/Nitrogen', 'CropType**3*sqrt(Nitrogen)',
       'Nitrogen**3*Phosphorous**2', 'CropType**2*sqrt(SoilType)',
       'CropType*sqrt(Phosphorous)', 'Nitrogen**3*sqrt(Potassium)',
       'sqrt(Nitrogen)*Phosphorous**2', 'Nitrogen**3*sqrt(Phosphorous)',
       'sqrt(Phosphorous)*Potassium**3', 'sqrt(Phosphorous)*log(Nitrogen)',
       'sqrt(Phosphorous)*sqrt(SoilType)', 'Potassium**3/Moisture',
       'exp(SoilType)/Moisture', 'Moisture*sqrt(SoilType)',
       'sqrt(CropType)*Moisture', 'Phosphorous**2/Nitrogen',
       'sqrt(SoilType)/Moisture', 'log(Nitrogen)/Moisture',
       'sqrt(SoilType)/Nitrogen', 'Nitrogen*exp(SoilType)',
       'CropType**3*sqrt(Phosphorous)', 'Nitrogen**3*SoilType',
       'sqrt(Nitrogen)*sqrt(Potassium)', 'N_P_ratio', 'N_K_ratio',
       'Nitrogen_mean', 'Nitrogen_std', 'Phosphorous_mean', 'Phosphorous_std',
       'Potassium_mean', 'Potassium_std', 'Moisture_mean', 'Moisture_std',
       'Temparature_mean', 'Soil_Crop_encoded']

# %%
# fertilizers = train["Fertilizer Name"].unique()

# # Step 3: Create transformed data
# transformed_data = []

# for _, row in train.iterrows():
#     group_id = row["id"]  
#     true_fertilizer = row["Fertilizer Name"]  
    
#     for fertilizer in fertilizers:
#         relevance = 1 if fertilizer == true_fertilizer else 0
#         new_row = row.to_dict()
#         new_row["fertilizer"] = fertilizer 
#         new_row["relevance"] = relevance 
#         transformed_data.append(new_row)

# expanded_df = pd.DataFrame(transformed_data)

# features = [col for col in expanded_df.columns if col not in ["Fertilizer Name", "fertilizer", "relevance", "id"]]
# X = expanded_df[features] 
# y = expanded_df["relevance"] 
# groups = expanded_df["id"].value_counts(sort=False).tolist()

# %%
# import xgboost as xgb

# cat_cols = ["Soil Type", "Crop Type"]  # Update with your actual categorical columns
# for col in cat_cols:
#     expanded_df[col] = expanded_df[col].astype("category")
# train_mask = expanded_df["id"].isin(train["id"].sample(frac=0.8, random_state=42))  # 80% train
# val_mask = ~expanded_df["id"].isin(train["id"].sample(frac=0.8, random_state=42))    # 20% val

# X_train, y_train = X[train_mask], y[train_mask]
# X_val, y_val = X[val_mask], y[val_mask]
# groups_train = groups[:int(0.8 * len(groups))]  
# groups_val = groups[int(0.8 * len(groups)):]  

# for col in cat_cols:
#     X_train[col] = X_train[col].astype("category")
#     X_val[col] = X_val[col].astype("category")


# dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)
# dval = xgb.DMatrix(X_val, label=y_val, enable_categorical=True)
# dtrain.set_group(groups_train)
# dval.set_group(groups_val)

# # Train with ranking objective
# params = {
#     "objective": "rank:pairwise",  # Ranking objective
#     "eval_metric": "map@3",        # Metric to optimize
#     "eta": 0.05,           # Lower learning rate
#     "max_depth": 6,        # Deeper trees
#     # "lambda": 1.0,         # L2 regularization
#     # "gamma": 0.1,          # Minimum loss reduction for splits
#     "min_child_weight": 1,
#     "subsample": 0.8,      # Prevent overfitting
#     "colsample_bytree": 0.7
# }

# model = xgb.train(
#     params,
#     dtrain,
#     num_boost_round=100,
#     evals=[(dval, "validation")]
# )

# %%
# n_features = int(X_train.shape[1])
# n_classes = int(y.nunique())

# %%
# class MAPK(tf.keras.metrics.Metric):
#     def __init__(self, k=3, name='mapk', **kwargs):
#         super(MAPK, self).__init__(name=name, **kwargs)
#         self.k = k
#         self.total = self.add_weight(name='total', initializer='zeros')
#         self.count = self.add_weight(name='count', initializer='zeros')

#     def update_state(self, y_true, y_pred, sample_weight=None):
#         # Fix: Keep y_pred as float32 for proper probability handling
#         y_true = tf.cast(y_true, tf.int32)
#         y_pred = tf.cast(y_pred, tf.float32)  # ← Don't cast to int32

#         # Get top-k indices
#         _, top_k_indices = tf.nn.top_k(y_pred, k=self.k)
#         top_k_indices = tf.reverse(top_k_indices, axis=[-1])

#         # Compute AP per sample
#         positions = tf.range(1, self.k + 1, dtype=tf.float32)
#         reciprocal_positions = 1.0 / positions

#         matches = tf.equal(tf.expand_dims(y_true, axis=1), top_k_indices)
#         matches_float = tf.cast(matches, tf.float32)

#         ap_per_sample = tf.reduce_sum(matches_float * reciprocal_positions, axis=1)
#         mean_ap = tf.reduce_mean(ap_per_sample)

#         self.total.assign_add(mean_ap)
#         self.count.assign_add(1.)

#     def result(self):
#         return self.total / self.count

#     def reset_states(self):
#         self.total.assign(0.)  # ← Use assign() instead of assign_add()
#         self.count.assign(0.)

# model = models.Sequential([
#     layers.Dense(512, activation='swish', input_dim=n_features, kernel_initializer='he_normal'),
#     layers.BatchNormalization(),
#     layers.Dropout(0.3),
    
#     layers.Dense(256, activation='swish', kernel_initializer='he_normal'),
#     layers.BatchNormalization(),
#     layers.Dropout(0.2),
    
#     layers.Dense(128, activation='swish', kernel_initializer='he_normal'),
#     layers.BatchNormalization(),
    
#     layers.Dense(n_classes, activation='softmax')
# ])

# optimizer = tf.keras.optimizers.Adam(
#     learning_rate=tf.keras.optimizers.schedules.ExponentialDecay(
#         initial_learning_rate=0.001,
#         decay_steps=1000,
#         decay_rate=0.9
#     ),
#     clipnorm=1.0
# )

# model.compile(
#     optimizer=optimizer,
#     loss='sparse_categorical_crossentropy',
#     metrics=[MAPK(k=3)]
# )

# # 4. Essential Callbacks
# callbacks = [
#     tf.keras.callbacks.EarlyStopping(
#         monitor='val_mapk',  # Monitor custom metric
#         mode='max',
#         patience=15,
#         restore_best_weights=True
#     ),
#     tf.keras.callbacks.ReduceLROnPlateau(
#         monitor='val_loss',
#         factor=0.5,
#         patience=5,
#         min_lr=1e-6
#     ),
#     tf.keras.callbacks.TerminateOnNaN()
# ]

# %%
# X_train = X_train.astype(np.float32)
# y_train = y_train.astype(np.int32)

# history = model.fit(
#     X_train, y_train,
#     validation_data=(X_valid, y_valid),
#     epochs=200,
#     batch_size=128,
#     callbacks=callbacks,
#     verbose=1
# )

# %%
cols = ['Temparature',
 'Humidity',
 'Moisture',
 'Soil Type',
 'Crop Type',
 'Nitrogen',
 'Potassium',
 'Phosphorous',
 # 'Phosphorous_mean',
 # 'Potassium_std',
 # 'Moisture_mean',
 # 'Potassium_mean',
 # 'Nitrogen_deficient',
 # 'Temparature_std',
 # 'Potassium_deficient',
 # 'Potassium_median',
 # 'Temparature_mean'
       ]

# %%
def trial_domain_features(df):
    df = df.copy()
    # NPK ratios are fundamental in agriculture
    # df['N_P_ratio'] = df['Nitrogen'] / (df['Phosphorous'] + 1e-6)
    # df['N_K_ratio'] = df['Nitrogen'] / (df['Potassium'] + 1e-6)
    # df['P_K_ratio'] = df['Phosphorous'] / (df['Potassium'] + 1e-6)

    # # Total NPK content
    # df['NPK_total'] = df['Nitrogen'] + df['Phosphorous'] + df['Potassium']

    # # Balanced vs imbalanced nutrients
    # df['NPK_balance'] = df[['Nitrogen', 'Phosphorous', 'Potassium']].std(axis=1)

    # Water stress indicator
    # df['water_stress'] = (df['Humidity'] < 40) & (df['Moisture'] < 30)

    # Heat stress
    # df['heat_stress'] = df['Temparature'] > 35

    # # Optimal growing conditions
    # df['optimal_temp_humidity'] = ((df['Temparature'] >= 20) & (df['Temparature'] <= 30) & 
    #                            (df['Humidity'] >= 50) & (df['Humidity'] <= 70))
    # Different crops have different NPK requirements
    # High N crops: leafy greens, corn
    # High P crops: root vegetables, flowering plants  
    # High K crops: fruits, stressed plants

    # df['high_N_crop'] = df['Crop Type'].isin(['Wheat', 'Maize', 'Rice', 'Sugarcane'])
    # df['high_P_crop'] = df['Crop Type'].isin(['Cotton', 'Groundnut'])
    # df['high_K_crop'] = df['Crop Type'].isin(['Banana', 'Grapes'])

    # # Interaction features
    # df['N_demand_match'] = df['Nitrogen'] * df['high_N_crop']
    # df['P_demand_match'] = df['Phosphorous'] * df['high_P_crop']
    # df['K_demand_match'] = df['Potassium'] * df['high_K_crop']
    # df['moisture_N_availability'] = df['Moisture'] * df['Nitrogen'] / 100
    # df['dry_soil_P_lockup'] = (df['Moisture'] < 25) * df['Phosphorous']

    # # Humidity affects disease pressure (impacts fertilizer strategy)
    # df['humid_disease_risk'] = (df['Humidity'] > 80) * 1
    
    df['N_deficient'] = df['Nitrogen'] < 20
    df['P_deficient'] = df['Phosphorous'] < 10  
    df['K_deficient'] = df['Potassium'] < 15

    # # Multiple deficiencies
    # df['multi_deficient'] = (df['N_deficient'] + df['P_deficient'] + df['K_deficient']) >= 2

    # # Severe deficiency
    # df['severe_deficiency'] = (df['Nitrogen'] < 10) | (df['Phosphorous'] < 5) | (df['Potassium'] < 8
    
    # df['vegetative_conditions'] = (df['Temparature'] >= 25) & (df['Humidity'] >= 60) & (df['Moisture'] >= 40)
    # df['reproductive_conditions'] = (df['Temparature'] <= 28) & (df['Phosphorous'] > df['Nitrogen'])
    # df['N_efficiency'] = df['Nitrogen'] / (df['Temparature'] + df['Moisture'])
    # df['moisture_nutrient_efficiency'] = df['NPK_total'] / (df['Moisture'] + 1)
    # df['temp_adjusted_NPK'] = df['NPK_total'] * (df['Temparature'] / 30)  # 30°C as reference
    # Clay soils bind phosphorus tightly (P-fixation)
    # df['clay_P_fixation'] = (df['Soil Type'] == 'Clayey') * df['Phosphorous']

    # Sandy soils have poor nutrient retention
    # df['sandy_nutrient_leaching'] = (df['Soil Type'] == 'Sandy') * df['NPK_total']

    # # Loamy soils have optimal nutrient availability
    # df['loamy_nutrient_efficiency'] = (df['Soil Type'] == 'Loamy') * df['NPK_total']

    # Sandy soils need more frequent, lighter applications
    # df['sandy_frequent_feeding'] = (df['Soil Type'] == 'Sandy') * 1
    # Clay holds water but may have drainage issues
    # df['clay_waterlogged_risk'] = (df['Soil Type'] == 'Clayey') & (df['Moisture'] > 70)

    # # Sandy drains fast, nutrients wash away
    # df['sandy_drought_stress'] = (df['Soil Type'] == 'Sandy') & (df['Moisture'] < 30)

    # # Soil-specific moisture effectiveness
    # df['clay_moisture_retention'] = (df['Soil Type'] == 'Clayey') * df['Moisture']
    # df['sandy_moisture_loss'] = (df['Soil Type'] == 'Sandy') * (100 - df['Moisture'])
    # df['soil_crop'] = df['Soil Type'].astype(str) + '_' + df['Crop Type'].astype(str)
    return df.copy()

X_trial = trial_domain_features(X_new[cols])
test_new = trial_domain_features(test_new[cols])

# %%
cat_trial_cols = ['Soil Type', 'Crop Type', 'Temparature', 'Humidity', 'Moisture', 'Nitrogen', 'Phosphorous', 'Potassium']
X_trial[cat_trial_cols] = X_trial[cat_trial_cols].astype('category')
test_new[cat_trial_cols] = test_new[cat_trial_cols].astype('category')

# %%
# X_trial.reset_index(drop=True, inplace=True)
# train_new.reset_index(drop=True, inplace=True)

# %%
# X_trial['Soil Type'] = train_new['Soil Type'].astype('category')
# X_trial['Crop Type'] = train_new['Crop Type'].astype('category')

# %%
# soil_type_dict = {
#     "Black": 0,
#     "Clayey": 1,
#     "Loamy": 2,
#     "Red": 3,
#     "Sandy": 4
# }
# crop_type_dict = {
#     "Barley": 0,
#     "Cotton": 1,
#     "Ground Nuts": 2,
#     "Maize": 3,
#     "Millets": 4,
#     "Oil seeds": 5,
#     "Paddy": 6,
#     "Pulses": 7,
#     "Sugarcane": 8,
#     "Tobacco": 9,
#     "Wheat": 10
# }
# X_trial['Soil Type'] = X_trial["Soil Type"].map(soil_type_dict).astype(int)
# X_trial['Crop Type'] = X_trial['Crop Type'].map(crop_type_dict).astype(int)

# %%
# X_trial[cols] = X_trial[cols].astype('float32')

# %%
# import seaborn as sns
# sns.histplot(X_trial['Potassium'], kde=True)
X_trial.dtypes
# Out:
# Temparature    category
# Humidity       category
# Moisture       category
# Soil Type      category
# Crop Type      category
# Nitrogen       category
# Potassium      category
# Phosphorous    category
# N_deficient        bool
# P_deficient        bool
# K_deficient        bool
# dtype: object

# %%
test_new.dtypes
# Out:
# Temparature    category
# Humidity       category
# Moisture       category
# Soil Type      category
# Crop Type      category
# Nitrogen       category
# Potassium      category
# Phosphorous    category
# N_deficient        bool
# P_deficient        bool
# K_deficient        bool
# dtype: object

# %%
X_trial.nunique()
# Out:
# Temparature    14
# Humidity       23
# Moisture       41
# Soil Type       5
# Crop Type      11
# Nitrogen       39
# Potassium      20
# Phosphorous    43
# N_deficient     2
# P_deficient     2
# K_deficient     2
# dtype: int64

# %%
# for col in cat_trial_cols:
#     X_trial[col] = X_trial[col].astype(str)

# %%
X_trial['const'] = 0
test_new['const'] = 0

# %%
def test_multiple_folds(X, y, test, model_dict, folds=folds):
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)
    test_preds_dict = {}
    results = {}

    for name, model in model_dict.items():
        n_classes = len(np.unique(y))
        oof_probas = np.zeros((len(X), n_classes))
        test_probas = np.zeros((len(test), n_classes))
        fold_scores = []
        for i, (train_idx, valid_idx) in enumerate(skf.split(X, y), 1):
            clf = clone(model)
            X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
            y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]
            clf.fit(X_train, y_train,
                   eval_set = [(X_valid, y_valid)],
                   eval_metric = 'mlogloss')
            valid_probas = clf.predict_proba(X_valid)
            score = mapk_score(y_valid, valid_probas, k=3)
            fold_scores.append(score)
            print(f'score for fold {i} is : {score}')
            oof_probas[valid_idx] = valid_probas
            test_probas+=clf.predict_proba(test)

        test_probas/=folds
        oof_score = mapk_score(y, oof_probas, k=3)
        results[name] = oof_score
        test_preds_dict[name] = test_probas
        print('----------')
        print(f'cv mean score : {np.mean(fold_scores)}')
        print(f'oofs mean score : {oof_score}')
        print('----------')
    return results, test_preds_dict

# %%
import xgboost as xgb
import catboost as cb 
import lightgbm as lgb
from sklearn.ensemble import HistGradientBoostingClassifier, ExtraTreesClassifier
import warnings 
warnings.filterwarnings('ignore')
params = {'n_estimators': 3373, 'learning_rate': 0.011259949991593646, 
'max_depth': 21, 'min_child_weight': 9.730207421568215, 'gamma': 1.9176916551823702,
'subsample': 0.6000599493499921, 'colsample_bytree': 0.6991286032909712, 'reg_alpha': 3.460930710395595, 
'reg_lambda': 1.6121748240796503, 'max_bin': 128, 'max_cat_threshold': 4, 'max_cat_to_onehot': 4,
'random_state':seed, 'tree_method': 'hist', 'device': 'cuda', 'enable_categorical':True}
model_dict = {
    # 'xgb_1': xgb.XGBClassifier(random_state=seed, tree_method='hist', device='cuda', enable_categorical=True),
    'xgb_1': xgb.XGBClassifier(**params)
    # 'cb': cb.CatBoostClassifier(random_state=seed, cat_features=cat_trial_cols, task_type='GPU', verbose=0)
    # 'etr_1': ExtraTreesClassifier(random_state=seed, n_jobs=-1),
    # 'lgb_1': lgb.LGBMClassifier(random_state=seed, categorical_feature=['Soil Type', 'Crop Type']),
    # 'hgb_1': HistGradientBoostingClassifier(random_state=seed, verbose=0,)
}

# results = cv_score(X_trial, y_full, model_dict)
# results = cv_score(X_trial, y_full, model_dict)

# %%
results, test_preds_dict = test_multiple_folds(X_trial, y_full, test_new, model_dict, folds)
# Out:
# [0]	validation_0-mlogloss:1.94573
# [1]	validation_0-mlogloss:1.94555
# [2]	validation_0-mlogloss:1.94540
# [3]	validation_0-mlogloss:1.94522
# [4]	validation_0-mlogloss:1.94505
# [5]	validation_0-mlogloss:1.94490
# [6]	validation_0-mlogloss:1.94472
# [7]	validation_0-mlogloss:1.94453
# [8]	validation_0-mlogloss:1.94434
# [9]	validation_0-mlogloss:1.94417
# [10]	validation_0-mlogloss:1.94400
# [11]	validation_0-mlogloss:1.94383
# [12]	validation_0-mlogloss:1.94366
# [13]	validation_0-mlogloss:1.94349
# [14]	validation_0-mlogloss:1.94335
# [15]	validation_0-mlogloss:1.94320
# [16]	validation_0-mlogloss:1.94304
# [17]	validation_0-mlogloss:1.94287
# [18]	validation_0-mlogloss:1.94270
# [19]	validation_0-mlogloss:1.94254
# [20]	validation_0-mlogloss:1.94238
# [21]	validation_0-mlogloss:1.94223
# [22]	validation_0-mlogloss:1.94206
# [23]	validation_0-mlogloss:1.94190
# [24]	validation_0-mlogloss:1.94176
# [25]	validation_0-mlogloss:1.94161
# [26]	validation_0-mlogloss:1.94147
# [27]	validation_0-mlogloss:1.94134
# [28]	validation_0-mlogloss:1.94119
# [29]	validation_0-mlogloss:1.94104
# [30]	validation_0-mlogloss:1.94087
# [31]	validation_0-mlogloss:1.94074
# [32]	validation_0-mlogloss:1.94057
# [33]	validation_0-mlogloss:1.94044
# [34]	validation_0-mlogloss:1.94029
# [35]	validation_0-mlogloss:1.94016
# [36]	validation_0-mlogloss:1.94003
# [37]	validation_0-mlogloss:1.93989
# [38]	validation_0-mlogloss:1.93975
# [39]	validation_0-mlogloss:1.93962
# [40]	validation_0-mlogloss:1.93949
# [41]	validation_0-mlogloss:1.93934
# [42]	validation_0-mlogloss:1.93919
# [43]	validation_0-mlogloss:1.93905
# [44]	validation_0-mlogloss:1.93893
# [45]	validation_0-mlogloss:1.93881
# [46]	validation_0-mlogloss:1.93867
# [47]	validation_0-mlogloss:1.93854
# [48]	validation_0-mlogloss:1.93842
# [49]	validation_0-mlogloss:1.93831
# [50]	validation_0-mlogloss:1.93818
# [51]	validation_0-mlogloss:1.93805
# [52]	validation_0-mlogloss:1.93794
# [53]	validation_0-mlogloss:1.93779
# [54]	validation_0-mlogloss:1.93765
# [55]	validation_0-mlogloss:1.93752
# [56]	validation_0-mlogloss:1.93739
# [57]	validation_0-mlogloss:1.93725
# [58]	validation_0-mlogloss:1.93714
# [59]	validation_0-mlogloss:1.93702
# [60]	validation_0-mlogloss:1.93689
# [61]	validation_0-mlogloss:1.93678
# [62]	validation_0-mlogloss:1.93666
# [63]	validation_0-mlogloss:1.93656
# [64]	validation_0-mlogloss:1.93645
# [65]	validation_0-mlogloss:1.93633
# [66]	validation_0-mlogloss:1.93621
# [67]	validation_0-mlogloss:1.93609
# [68]	validation_0-mlogloss:1.93597
# [69]	validation_0-mlogloss:1.93586
# [70]	validation_0-mlogloss:1.93572
# [71]	validation_0-mlogloss:1.93560
# [72]	validation_0-mlogloss:1.93548
# [73]	validation_0-mlogloss:1.93537
# [74]	validation_0-mlogloss:1.93524
# [75]	validation_0-mlogloss:1.93513
# [76]	validation_0-mlogloss:1.93501
# [77]	validation_0-mlogloss:1.93490
# [78]	validation_0-mlogloss:1.93478
# [79]	validation_0-mlogloss:1.93467
# [80]	validation_0-mlogloss:1.93455
# [81]	validation_0-mlogloss:1.93443
# [82]	validation_0-mlogloss:1.93432
# [83]	validation_0-mlogloss:1.93418
# [84]	validation_0-mlogloss:1.93408
# [85]	validation_0-mlogloss:1.93397
# [86]	validation_0-mlogloss:1.93387
# [87]	validation_0-mlogloss:1.93377
# [88]	validation_0-mlogloss:1.93365
# [89]	validation_0-mlogloss:1.93354
# [90]	validation_0-mlogloss:1.93344
# [91]	validation_0-mlogloss:1.93334
# [92]	validation_0-mlogloss:1.93321
# [93]	validation_0-mlogloss:1.93312
# [94]	validation_0-mlogloss:1.93301
# [95]	validation_0-mlogloss:1.93290
# [96]	validation_0-mlogloss:1.93280
# [97]	validation_0-mlogloss:1.93271
# [98]	validation_0-mlogloss:1.93261
# [99]	validation_0-mlogloss:1.93250
# [100]	validation_0-mlogloss:1.93240
# [101]	validation_0-mlogloss:1.93230
# [102]	validation_0-mlogloss:1.93220
# [103]	validation_0-mlogloss:1.93209
# [104]	validation_0-mlogloss:1.93201
# [105]	validation_0-mlogloss:1.93191
# [106]	validation_0-mlogloss:1.93180
# [107]	validation_0-mlogloss:1.93170
# [108]	validation_0-mlogloss:1.93160
# [109]	validation_0-mlogloss:1.93151
# [110]	validation_0-mlogloss:1.93142
# [111]	validation_0-mlogloss:1.93130
# [112]	validation_0-mlogloss:1.93121
# [113]	validation_0-mlogloss:1.93112
# [114]	validation_0-mlogloss:1.93101
# [115]	validation_0-mlogloss:1.93092
# [116]	validation_0-mlogloss:1.93083
# [117]	validation_0-mlogloss:1.93075
# [118]	validation_0-mlogloss:1.93068
# [119]	validation_0-mlogloss:1.93061
# [120]	validation_0-mlogloss:1.93051
# [121]	validation_0-mlogloss:1.93040
# [122]	validation_0-mlogloss:1.93031
# [123]	validation_0-mlogloss:1.93023
# [124]	validation_0-mlogloss:1.93014
# [125]	validation_0-mlogloss:1.93004
# [126]	validation_0-mlogloss:1.92994
# [127]	validation_0-mlogloss:1.92986
# [128]	validation_0-mlogloss:1.92979
# [129]	validation_0-mlogloss:1.92970
# [130]	validation_0-mlogloss:1.92961
# [131]	validation_0-mlogloss:1.92952
# [132]	validation_0-mlogloss:1.92943
# [133]	validation_0-mlogloss:1.92936
# [134]	validation_0-mlogloss:1.92927
# [135]	validation_0-mlogloss:1.92919
# [136]	validation_0-mlogloss:1.92910
# [137]	validation_0-mlogloss:1.92902
# [138]	validation_0-mlogloss:1.92894
# [139]	validation_0-mlogloss:1.92885
# [140]	validation_0-mlogloss:1.92877
# [141]	validation_0-mlogloss:1.92869
# [142]	validation_0-mlogloss:1.92862
# [143]	validation_0-mlogloss:1.92852
# [144]	validation_0-mlogloss:1.92843
# [145]	validation_0-mlogloss:1.92836
# [146]	validation_0-mlogloss:1.92828
# [147]	validation_0-mlogloss:1.92820
# [148]	validation_0-mlogloss:1.92813
# [149]	validation_0-mlogloss:1.92805
# [150]	validation_0-mlogloss:1.92797
# [151]	validation_0-mlogloss:1.92789
# [152]	validation_0-mlogloss:1.92781
# [153]	validation_0-mlogloss:1.92772
# [154]	validation_0-mlogloss:1.92763
# [155]	validation_0-mlogloss:1.92757
# [156]	validation_0-mlogloss:1.92749
# [157]	validation_0-mlogloss:1.92742
# [158]	validation_0-mlogloss:1.92734
# [159]	validation_0-mlogloss:1.92726
# [160]	validation_0-mlogloss:1.92718
# [161]	validation_0-mlogloss:1.92710
# [162]	validation_0-mlogloss:1.92702
# [163]	validation_0-mlogloss:1.92693
# [164]	validation_0-mlogloss:1.92686
# [165]	validation_0-mlogloss:1.92678
# [166]	validation_0-mlogloss:1.92671
# [167]	validation_0-mlogloss:1.92664
# [168]	validation_0-mlogloss:1.92655
# [169]	validation_0-mlogloss:1.92648
# [170]	validation_0-mlogloss:1.92641
# [171]	validation_0-mlogloss:1.92633
# [172]	validation_0-mlogloss:1.92626
# [173]	validation_0-mlogloss:1.92619
# [174]	validation_0-mlogloss:1.92611
# [175]	validation_0-mlogloss:1.92604
# [176]	validation_0-mlogloss:1.92597
# [177]	validation_0-mlogloss:1.92590
# [178]	validation_0-mlogloss:1.92584
# [179]	validation_0-mlogloss:1.92577
# [180]	validation_0-mlogloss:1.92570
# [181]	validation_0-mlogloss:1.92562
# [182]	validation_0-mlogloss:1.92555
# [183]	validation_0-mlogloss:1.92547
# [184]	validation_0-mlogloss:1.92540
# [185]	validation_0-mlogloss:1.92532
# [186]	validation_0-mlogloss:1.92525
# [187]	validation_0-mlogloss:1.92518
# [188]	validation_0-mlogloss:1.92511
# [189]	validation_0-mlogloss:1.92505
# [190]	validation_0-mlogloss:1.92497
# [191]	validation_0-mlogloss:1.92489
# [192]	validation_0-mlogloss:1.92481
# [193]	validation_0-mlogloss:1.92475
# [194]	validation_0-mlogloss:1.92468
# [195]	validation_0-mlogloss:1.92462
# [196]	validation_0-mlogloss:1.92456
# [197]	validation_0-mlogloss:1.92450
# [198]	validation_0-mlogloss:1.92442
# [199]	validation_0-mlogloss:1.92435
# [200]	validation_0-mlogloss:1.92429
# [201]	validation_0-mlogloss:1.92424
# [202]	validation_0-mlogloss:1.92418
# [203]	validation_0-mlogloss:1.92412
# [204]	validation_0-mlogloss:1.92406
# [205]	validation_0-mlogloss:1.92400
# [206]	validation_0-mlogloss:1.92394
# [207]	validation_0-mlogloss:1.92388
# [208]	validation_0-mlogloss:1.92382
# [209]	validation_0-mlogloss:1.92376
# [210]	validation_0-mlogloss:1.92370
# [211]	validation_0-mlogloss:1.92363
# [212]	validation_0-mlogloss:1.92357
# [213]	validation_0-mlogloss:1.92350
# [214]	validation_0-mlogloss:1.92344
# [215]	validation_0-mlogloss:1.92337
# [216]	validation_0-mlogloss:1.92330
# [217]	validation_0-mlogloss:1.92324
# [218]	validation_0-mlogloss:1.92317
# [219]	validation_0-mlogloss:1.92312
# [220]	validation_0-mlogloss:1.92307
# [221]	validation_0-mlogloss:1.92300
# [222]	validation_0-mlogloss:1.92294
# [223]	validation_0-mlogloss:1.92288
# [224]	validation_0-mlogloss:1.92282
# [225]	validation_0-mlogloss:1.92278
# [226]	validation_0-mlogloss:1.92271
# [227]	validation_0-mlogloss:1.92264
# [228]	validation_0-mlogloss:1.92260
# [229]	validation_0-mlogloss:1.92254
# [230]	validation_0-mlogloss:1.92247
# [231]	validation_0-mlogloss:1.92243
# [232]	validation_0-mlogloss:1.92237
# [233]	validation_0-mlogloss:1.92232
# [234]	validation_0-mlogloss:1.92226
# [235]	validation_0-mlogloss:1.92220
# [236]	validation_0-mlogloss:1.92214
# [237]	validation_0-mlogloss:1.92209
# [238]	validation_0-mlogloss:1.92202
# [239]	validation_0-mlogloss:1.92196
# [240]	validation_0-mlogloss:1.92190
# [241]	validation_0-mlogloss:1.92184
# [242]	validation_0-mlogloss:1.92178
# [243]	validation_0-mlogloss:1.92172
# [244]	validation_0-mlogloss:1.92166
# [245]	validation_0-mlogloss:1.92161
# [246]	validation_0-mlogloss:1.92155
# [247]	validation_0-mlogloss:1.92150
# [248]	validation_0-mlogloss:1.92145
# [249]	validation_0-mlogloss:1.92140
# [250]	validation_0-mlogloss:1.92134
# [251]	validation_0-mlogloss:1.92129
# [252]	validation_0-mlogloss:1.92124
# [253]	validation_0-mlogloss:1.92118
# [254]	validation_0-mlogloss:1.92113
# [255]	validation_0-mlogloss:1.92107
# [256]	validation_0-mlogloss:1.92102
# [257]	validation_0-mlogloss:1.92096
# [258]	validation_0-mlogloss:1.92091
# [259]	validation_0-mlogloss:1.92087
# [260]	validation_0-mlogloss:1.92082
# [261]	validation_0-mlogloss:1.92078
# [262]	validation_0-mlogloss:1.92072
# [263]	validation_0-mlogloss:1.92066
# [264]	validation_0-mlogloss:1.92061
# [265]	validation_0-mlogloss:1.92056
# [266]	validation_0-mlogloss:1.92051
# [267]	validation_0-mlogloss:1.92045
# [268]	validation_0-mlogloss:1.92041
# [269]	validation_0-mlogloss:1.92035
# [270]	validation_0-mlogloss:1.92029
# [271]	validation_0-mlogloss:1.92024
# [272]	validation_0-mlogloss:1.92018
# [273]	validation_0-mlogloss:1.92012
# [274]	validation_0-mlogloss:1.92008
# [275]	validation_0-mlogloss:1.92003
# [276]	validation_0-mlogloss:1.91998
# [277]	validation_0-mlogloss:1.91993
# [278]	validation_0-mlogloss:1.91986
# [279]	validation_0-mlogloss:1.91982
# [280]	validation_0-mlogloss:1.91977
# [281]	validation_0-mlogloss:1.91972
# [282]	validation_0-mlogloss:1.91967
# [283]	validation_0-mlogloss:1.91964
# [284]	validation_0-mlogloss:1.91959
# [285]	validation_0-mlogloss:1.91954
# [286]	validation_0-mlogloss:1.91948
# [287]	validation_0-mlogloss:1.91944
# [288]	validation_0-mlogloss:1.91939
# [289]	validation_0-mlogloss:1.91935
# [290]	validation_0-mlogloss:1.91929
# [291]	validation_0-mlogloss:1.91926
# [292]	validation_0-mlogloss:1.91920
# [293]	validation_0-mlogloss:1.91915
# [294]	validation_0-mlogloss:1.91911
# [295]	validation_0-mlogloss:1.91906
# [296]	validation_0-mlogloss:1.91902
# [297]	validation_0-mlogloss:1.91896
# [298]	validation_0-mlogloss:1.91890
# [299]	validation_0-mlogloss:1.91886
# [300]	validation_0-mlogloss:1.91881
# [301]	validation_0-mlogloss:1.91876
# [302]	validation_0-mlogloss:1.91871
# [303]	validation_0-mlogloss:1.91866
# [304]	validation_0-mlogloss:1.91861
# [305]	validation_0-mlogloss:1.91856
# [306]	validation_0-mlogloss:1.91850
# [307]	validation_0-mlogloss:1.91844
# [308]	validation_0-mlogloss:1.91840
# [309]	validation_0-mlogloss:1.91835
# [310]	validation_0-mlogloss:1.91831
# [311]	validation_0-mlogloss:1.91826
# [312]	validation_0-mlogloss:1.91821
# [313]	validation_0-mlogloss:1.91816
# [314]	validation_0-mlogloss:1.91811
# [315]	validation_0-mlogloss:1.91807
# [316]	validation_0-mlogloss:1.91803
# [317]	validation_0-mlogloss:1.91799
# [318]	validation_0-mlogloss:1.91794
# [319]	validation_0-mlogloss:1.91789
# [320]	validation_0-mlogloss:1.91784
# [321]	validation_0-mlogloss:1.91779
# [322]	validation_0-mlogloss:1.91774
# [323]	validation_0-mlogloss:1.91769
# [324]	validation_0-mlogloss:1.91764
# [325]	validation_0-mlogloss:1.91759
# [326]	validation_0-mlogloss:1.91755
# [327]	validation_0-mlogloss:1.91751
# [328]	validation_0-mlogloss:1.91747
# [329]	validation_0-mlogloss:1.91743
# [330]	validation_0-mlogloss:1.91738
# [331]	validation_0-mlogloss:1.91733
# [332]	validation_0-mlogloss:1.91728
# [333]	validation_0-mlogloss:1.91724
# [334]	validation_0-mlogloss:1.91720
# [335]	validation_0-mlogloss:1.91716
# [336]	validation_0-mlogloss:1.91712
# [337]	validation_0-mlogloss:1.91707
# [338]	validation_0-mlogloss:1.91703
# [339]	validation_0-mlogloss:1.91698
# [340]	validation_0-mlogloss:1.91695
# [341]	validation_0-mlogloss:1.91691
# [342]	validation_0-mlogloss:1.91686
# [343]	validation_0-mlogloss:1.91681
# [344]	validation_0-mlogloss:1.91676
# [345]	validation_0-mlogloss:1.91672
# [346]	validation_0-mlogloss:1.91666
# [347]	validation_0-mlogloss:1.91662
# [348]	validation_0-mlogloss:1.91658
# [349]	validation_0-mlogloss:1.91654
# [350]	validation_0-mlogloss:1.91648
# [351]	validation_0-mlogloss:1.91644
# [352]	validation_0-mlogloss:1.91640
# [353]	validation_0-mlogloss:1.91636
# [354]	validation_0-mlogloss:1.91632
# [355]	validation_0-mlogloss:1.91626
# [356]	validation_0-mlogloss:1.91620
# [357]	validation_0-mlogloss:1.91617
# [358]	validation_0-mlogloss:1.91613
# [359]	validation_0-mlogloss:1.91609
# [360]	validation_0-mlogloss:1.91604
# [361]	validation_0-mlogloss:1.91600
# [362]	validation_0-mlogloss:1.91596
# [363]	validation_0-mlogloss:1.91592
# [364]	validation_0-mlogloss:1.91587
# [365]	validation_0-mlogloss:1.91583
# [366]	validation_0-mlogloss:1.91579
# [367]	validation_0-mlogloss:1.91575
# [368]	validation_0-mlogloss:1.91571
# [369]	validation_0-mlogloss:1.91567
# [370]	validation_0-mlogloss:1.91563
# [371]	validation_0-mlogloss:1.91559
# [372]	validation_0-mlogloss:1.91555
# [373]	validation_0-mlogloss:1.91551
# [374]	validation_0-mlogloss:1.91547
# [375]	validation_0-mlogloss:1.91545
# [376]	validation_0-mlogloss:1.91540
# [377]	validation_0-mlogloss:1.91536
# [378]	validation_0-mlogloss:1.91532
# [379]	validation_0-mlogloss:1.91528
# [380]	validation_0-mlogloss:1.91523
# [381]	validation_0-mlogloss:1.91519
# [382]	validation_0-mlogloss:1.91515
# [383]	validation_0-mlogloss:1.91512
# [384]	validation_0-mlogloss:1.91508
# [385]	validation_0-mlogloss:1.91504
# [386]	validation_0-mlogloss:1.91500
# [387]	validation_0-mlogloss:1.91495
# [388]	validation_0-mlogloss:1.91490
# [389]	validation_0-mlogloss:1.91486
# [390]	validation_0-mlogloss:1.91482
# [391]	validation_0-mlogloss:1.91479
# [392]	validation_0-mlogloss:1.91474
# [393]	validation_0-mlogloss:1.91469
# [394]	validation_0-mlogloss:1.91465
# [395]	validation_0-mlogloss:1.91461
# [396]	validation_0-mlogloss:1.91457
# [397]	validation_0-mlogloss:1.91452
# [398]	validation_0-mlogloss:1.91447
# [399]	validation_0-mlogloss:1.91444
# [400]	validation_0-mlogloss:1.91439
# [401]	validation_0-mlogloss:1.91436
# [402]	validation_0-mlogloss:1.91433
# [403]	validation_0-mlogloss:1.91429
# [404]	validation_0-mlogloss:1.91425
# [405]	validation_0-mlogloss:1.91420
# [406]	validation_0-mlogloss:1.91416
# [407]	validation_0-mlogloss:1.91411
# [408]	validation_0-mlogloss:1.91408
# [409]	validation_0-mlogloss:1.91404
# [410]	validation_0-mlogloss:1.91399
# [411]	validation_0-mlogloss:1.91395
# [412]	validation_0-mlogloss:1.91391
# [413]	validation_0-mlogloss:1.91387
# [414]	validation_0-mlogloss:1.91383
# [415]	validation_0-mlogloss:1.91379
# [416]	validation_0-mlogloss:1.91376
# [417]	validation_0-mlogloss:1.91371
# [418]	validation_0-mlogloss:1.91368
# [419]	validation_0-mlogloss:1.91364
# [420]	validation_0-mlogloss:1.91359
# [421]	validation_0-mlogloss:1.91355
# [422]	validation_0-mlogloss:1.91352
# [423]	validation_0-mlogloss:1.91348
# [424]	validation_0-mlogloss:1.91345
# [425]	validation_0-mlogloss:1.91340
# [426]	validation_0-mlogloss:1.91337
# [427]	validation_0-mlogloss:1.91332
# [428]	validation_0-mlogloss:1.91328
# [429]	validation_0-mlogloss:1.91324
# [430]	validation_0-mlogloss:1.91320
# [431]	validation_0-mlogloss:1.91316
# [432]	validation_0-mlogloss:1.91312
# [433]	validation_0-mlogloss:1.91309
# [434]	validation_0-mlogloss:1.91305
# [435]	validation_0-mlogloss:1.91301
# [436]	validation_0-mlogloss:1.91297
# [437]	validation_0-mlogloss:1.91294
# [438]	validation_0-mlogloss:1.91291
# [439]	validation_0-mlogloss:1.91288
# [440]	validation_0-mlogloss:1.91285
# [441]	validation_0-mlogloss:1.91280
# [442]	validation_0-mlogloss:1.91277
# [443]	validation_0-mlogloss:1.91273
# [444]	validation_0-mlogloss:1.91271
# [445]	validation_0-mlogloss:1.91267
# [446]	validation_0-mlogloss:1.91263
# [447]	validation_0-mlogloss:1.91259
# [448]	validation_0-mlogloss:1.91255
# [449]	validation_0-mlogloss:1.91251
# [450]	validation_0-mlogloss:1.91247
# [451]	validation_0-mlogloss:1.91244
# [452]	validation_0-mlogloss:1.91240
# [453]	validation_0-mlogloss:1.91236
# [454]	validation_0-mlogloss:1.91232
# [455]	validation_0-mlogloss:1.91228
# [456]	validation_0-mlogloss:1.91225
# [457]	validation_0-mlogloss:1.91220
# [458]	validation_0-mlogloss:1.91216
# [459]	validation_0-mlogloss:1.91213
# [460]	validation_0-mlogloss:1.91210
# [461]	validation_0-mlogloss:1.91207
# [462]	validation_0-mlogloss:1.91203
# [463]	validation_0-mlogloss:1.91200
# [464]	validation_0-mlogloss:1.91197
# [465]	validation_0-mlogloss:1.91193
# [466]	validation_0-mlogloss:1.91189
# [467]	validation_0-mlogloss:1.91186
# [468]	validation_0-mlogloss:1.91182
# [469]	validation_0-mlogloss:1.91179
# [470]	validation_0-mlogloss:1.91174
# [471]	validation_0-mlogloss:1.91171
# [472]	validation_0-mlogloss:1.91167
# [473]	validation_0-mlogloss:1.91164
# [474]	validation_0-mlogloss:1.91159
# [475]	validation_0-mlogloss:1.91156
# [476]	validation_0-mlogloss:1.91152
# [477]	validation_0-mlogloss:1.91148
# [478]	validation_0-mlogloss:1.91145
# [479]	validation_0-mlogloss:1.91142
# [480]	validation_0-mlogloss:1.91138
# [481]	validation_0-mlogloss:1.91135
# [482]	validation_0-mlogloss:1.91131
# [483]	validation_0-mlogloss:1.91128
# [484]	validation_0-mlogloss:1.91124
# [485]	validation_0-mlogloss:1.91120
# [486]	validation_0-mlogloss:1.91118
# [487]	validation_0-mlogloss:1.91115
# [488]	validation_0-mlogloss:1.91112
# [489]	validation_0-mlogloss:1.91109
# [490]	validation_0-mlogloss:1.91105
# [491]	validation_0-mlogloss:1.91102
# [492]	validation_0-mlogloss:1.91099
# [493]	validation_0-mlogloss:1.91096
# [494]	validation_0-mlogloss:1.91093
# [495]	validation_0-mlogloss:1.91089
# [496]	validation_0-mlogloss:1.91086
# [497]	validation_0-mlogloss:1.91083
# [498]	validation_0-mlogloss:1.91080
# [499]	validation_0-mlogloss:1.91077
# [500]	validation_0-mlogloss:1.91075
# [501]	validation_0-mlogloss:1.91072
# [502]	validation_0-mlogloss:1.91068
# [503]	validation_0-mlogloss:1.91064
# [504]	validation_0-mlogloss:1.91060
# [505]	validation_0-mlogloss:1.91057
# [506]	validation_0-mlogloss:1.91054
# [507]	validation_0-mlogloss:1.91050
# [508]	validation_0-mlogloss:1.91048
# [509]	validation_0-mlogloss:1.91044
# [510]	validation_0-mlogloss:1.91040
# [511]	validation_0-mlogloss:1.91036
# [512]	validation_0-mlogloss:1.91033
# [513]	validation_0-mlogloss:1.91030
# [514]	validation_0-mlogloss:1.91025
# [515]	validation_0-mlogloss:1.91022
# [516]	validation_0-mlogloss:1.91018
# [517]	validation_0-mlogloss:1.91015
# [518]	validation_0-mlogloss:1.91012
# [519]	validation_0-mlogloss:1.91010
# [520]	validation_0-mlogloss:1.91006
# [521]	validation_0-mlogloss:1.91004
# [522]	validation_0-mlogloss:1.91000
# [523]	validation_0-mlogloss:1.90997
# [524]	validation_0-mlogloss:1.90993
# [525]	validation_0-mlogloss:1.90990
# [526]	validation_0-mlogloss:1.90986
# [527]	validation_0-mlogloss:1.90983
# [528]	validation_0-mlogloss:1.90980
# [529]	validation_0-mlogloss:1.90977
# [530]	validation_0-mlogloss:1.90974
# [531]	validation_0-mlogloss:1.90973
# [532]	validation_0-mlogloss:1.90970
# [533]	validation_0-mlogloss:1.90965
# [534]	validation_0-mlogloss:1.90961
# [535]	validation_0-mlogloss:1.90958
# [536]	validation_0-mlogloss:1.90955
# [537]	validation_0-mlogloss:1.90952
# [538]	validation_0-mlogloss:1.90949
# [539]	validation_0-mlogloss:1.90945
# [540]	validation_0-mlogloss:1.90943
# [541]	validation_0-mlogloss:1.90940
# [542]	validation_0-mlogloss:1.90937
# [543]	validation_0-mlogloss:1.90933
# [544]	validation_0-mlogloss:1.90930
# [545]	validation_0-mlogloss:1.90927
# [546]	validation_0-mlogloss:1.90923
# [547]	validation_0-mlogloss:1.90918
# [548]	validation_0-mlogloss:1.90915
# [549]	validation_0-mlogloss:1.90912
# [550]	validation_0-mlogloss:1.90910
# [551]	validation_0-mlogloss:1.90907
# [552]	validation_0-mlogloss:1.90903
# [553]	validation_0-mlogloss:1.90901
# [554]	validation_0-mlogloss:1.90898
# [555]	validation_0-mlogloss:1.90894
# [556]	validation_0-mlogloss:1.90892
# [557]	validation_0-mlogloss:1.90890
# [558]	validation_0-mlogloss:1.90886
# [559]	validation_0-mlogloss:1.90884
# [560]	validation_0-mlogloss:1.90881
# [561]	validation_0-mlogloss:1.90877
# [562]	validation_0-mlogloss:1.90874
# [563]	validation_0-mlogloss:1.90870
# [564]	validation_0-mlogloss:1.90868
# [565]	validation_0-mlogloss:1.90864
# [566]	validation_0-mlogloss:1.90861
# [567]	validation_0-mlogloss:1.90858
# [568]	validation_0-mlogloss:1.90854
# [569]	validation_0-mlogloss:1.90851
# [570]	validation_0-mlogloss:1.90848
# [571]	validation_0-mlogloss:1.90845
# [572]	validation_0-mlogloss:1.90842
# [573]	validation_0-mlogloss:1.90839
# [574]	validation_0-mlogloss:1.90836
# [575]	validation_0-mlogloss:1.90833
# [576]	validation_0-mlogloss:1.90830
# [577]	validation_0-mlogloss:1.90827
# [578]	validation_0-mlogloss:1.90824
# [579]	validation_0-mlogloss:1.90821
# [580]	validation_0-mlogloss:1.90818
# [581]	validation_0-mlogloss:1.90816
# [582]	validation_0-mlogloss:1.90812
# [583]	validation_0-mlogloss:1.90809
# [584]	validation_0-mlogloss:1.90806
# [585]	validation_0-mlogloss:1.90803
# [586]	validation_0-mlogloss:1.90799
# [587]	validation_0-mlogloss:1.90795
# [588]	validation_0-mlogloss:1.90793
# [589]	validation_0-mlogloss:1.90790
# [590]	validation_0-mlogloss:1.90786
# [591]	validation_0-mlogloss:1.90783
# [592]	validation_0-mlogloss:1.90780
# [593]	validation_0-mlogloss:1.90777
# [594]	validation_0-mlogloss:1.90773
# [595]	validation_0-mlogloss:1.90770
# [596]	validation_0-mlogloss:1.90767
# [597]	validation_0-mlogloss:1.90765
# [598]	validation_0-mlogloss:1.90762
# [599]	validation_0-mlogloss:1.90759
# [600]	validation_0-mlogloss:1.90756
# [601]	validation_0-mlogloss:1.90753
# [602]	validation_0-mlogloss:1.90750
# [603]	validation_0-mlogloss:1.90749
# [604]	validation_0-mlogloss:1.90745
# [605]	validation_0-mlogloss:1.90742
# [606]	validation_0-mlogloss:1.90740
# [607]	validation_0-mlogloss:1.90737
# [608]	validation_0-mlogloss:1.90735
# [609]	validation_0-mlogloss:1.90733
# [610]	validation_0-mlogloss:1.90730
# [611]	validation_0-mlogloss:1.90727
# [612]	validation_0-mlogloss:1.90725
# [613]	validation_0-mlogloss:1.90722
# [614]	validation_0-mlogloss:1.90720
# [615]	validation_0-mlogloss:1.90717
# [616]	validation_0-mlogloss:1.90715
# [617]	validation_0-mlogloss:1.90712
# [618]	validation_0-mlogloss:1.90710
# [619]	validation_0-mlogloss:1.90706
# [620]	validation_0-mlogloss:1.90704
# [621]	validation_0-mlogloss:1.90702
# [622]	validation_0-mlogloss:1.90699
# [623]	validation_0-mlogloss:1.90696
# [624]	validation_0-mlogloss:1.90693
# [625]	validation_0-mlogloss:1.90691
# [626]	validation_0-mlogloss:1.90688
# [627]	validation_0-mlogloss:1.90685
# [628]	validation_0-mlogloss:1.90683
# [629]	validation_0-mlogloss:1.90681
# [630]	validation_0-mlogloss:1.90678
# [631]	validation_0-mlogloss:1.90676
# [632]	validation_0-mlogloss:1.90673
# [633]	validation_0-mlogloss:1.90670
# [634]	validation_0-mlogloss:1.90667
# [635]	validation_0-mlogloss:1.90665
# [636]	validation_0-mlogloss:1.90662
# [637]	validation_0-mlogloss:1.90660
# [638]	validation_0-mlogloss:1.90657
# [639]	validation_0-mlogloss:1.90655
# [640]	validation_0-mlogloss:1.90652
# [641]	validation_0-mlogloss:1.90649
# [642]	validation_0-mlogloss:1.90646
# [643]	validation_0-mlogloss:1.90644
# [644]	validation_0-mlogloss:1.90641
# [645]	validation_0-mlogloss:1.90638
# [646]	validation_0-mlogloss:1.90634
# [647]	validation_0-mlogloss:1.90631
# [648]	validation_0-mlogloss:1.90629
# [649]	validation_0-mlogloss:1.90626
# [650]	validation_0-mlogloss:1.90623
# [651]	validation_0-mlogloss:1.90621
# [652]	validation_0-mlogloss:1.90617
# [653]	validation_0-mlogloss:1.90615
# [654]	validation_0-mlogloss:1.90612
# [655]	validation_0-mlogloss:1.90609
# [656]	validation_0-mlogloss:1.90607
# [657]	validation_0-mlogloss:1.90604
# [658]	validation_0-mlogloss:1.90601
# [659]	validation_0-mlogloss:1.90598
# [660]	validation_0-mlogloss:1.90595
# [661]	validation_0-mlogloss:1.90592
# [662]	validation_0-mlogloss:1.90589
# [663]	validation_0-mlogloss:1.90587
# [664]	validation_0-mlogloss:1.90584
# [665]	validation_0-mlogloss:1.90582
# [666]	validation_0-mlogloss:1.90580
# [667]	validation_0-mlogloss:1.90577
# [668]	validation_0-mlogloss:1.90573
# [669]	validation_0-mlogloss:1.90571
# [670]	validation_0-mlogloss:1.90568
# [671]	validation_0-mlogloss:1.90565
# [672]	validation_0-mlogloss:1.90563
# [673]	validation_0-mlogloss:1.90559
# [674]	validation_0-mlogloss:1.90556
# [675]	validation_0-mlogloss:1.90553
# [676]	validation_0-mlogloss:1.90550
# [677]	validation_0-mlogloss:1.90547
# [678]	validation_0-mlogloss:1.90544
# [679]	validation_0-mlogloss:1.90541
# [680]	validation_0-mlogloss:1.90538
# [681]	validation_0-mlogloss:1.90535
# [682]	validation_0-mlogloss:1.90533
# [683]	validation_0-mlogloss:1.90529
# [684]	validation_0-mlogloss:1.90525
# [685]	validation_0-mlogloss:1.90523
# [686]	validation_0-mlogloss:1.90520
# [687]	validation_0-mlogloss:1.90516
# [688]	validation_0-mlogloss:1.90514
# [689]	validation_0-mlogloss:1.90512
# [690]	validation_0-mlogloss:1.90510
# [691]	validation_0-mlogloss:1.90507
# [692]	validation_0-mlogloss:1.90504
# [693]	validation_0-mlogloss:1.90502
# [694]	validation_0-mlogloss:1.90500
# [695]	validation_0-mlogloss:1.90497
# [696]	validation_0-mlogloss:1.90494
# [697]	validation_0-mlogloss:1.90492
# [698]	validation_0-mlogloss:1.90490
# [699]	validation_0-mlogloss:1.90487
# [700]	validation_0-mlogloss:1.90485
# [701]	validation_0-mlogloss:1.90481
# [702]	validation_0-mlogloss:1.90479
# [703]	validation_0-mlogloss:1.90477
# [704]	validation_0-mlogloss:1.90475
# [705]	validation_0-mlogloss:1.90473
# [706]	validation_0-mlogloss:1.90471
# [707]	validation_0-mlogloss:1.90469
# [708]	validation_0-mlogloss:1.90466
# [709]	validation_0-mlogloss:1.90463
# [710]	validation_0-mlogloss:1.90460
# [711]	validation_0-mlogloss:1.90457
# [712]	validation_0-mlogloss:1.90455
# [713]	validation_0-mlogloss:1.90452
# [714]	validation_0-mlogloss:1.90451
# [715]	validation_0-mlogloss:1.90448
# [716]	validation_0-mlogloss:1.90445
# [717]	validation_0-mlogloss:1.90443
# [718]	validation_0-mlogloss:1.90440
# [719]	validation_0-mlogloss:1.90437
# [720]	validation_0-mlogloss:1.90435
# [721]	validation_0-mlogloss:1.90431
# [722]	validation_0-mlogloss:1.90429
# [723]	validation_0-mlogloss:1.90427
# [724]	validation_0-mlogloss:1.90424
# [725]	validation_0-mlogloss:1.90422
# [726]	validation_0-mlogloss:1.90420
# [727]	validation_0-mlogloss:1.90416
# [728]	validation_0-mlogloss:1.90414
# [729]	validation_0-mlogloss:1.90411
# [730]	validation_0-mlogloss:1.90409
# [731]	validation_0-mlogloss:1.90406
# [732]	validation_0-mlogloss:1.90404
# [733]	validation_0-mlogloss:1.90401
# [734]	validation_0-mlogloss:1.90399
# [735]	validation_0-mlogloss:1.90397
# [736]	validation_0-mlogloss:1.90394
# [737]	validation_0-mlogloss:1.90392
# [738]	validation_0-mlogloss:1.90390
# [739]	validation_0-mlogloss:1.90388
# [740]	validation_0-mlogloss:1.90385
# [741]	validation_0-mlogloss:1.90382
# [742]	validation_0-mlogloss:1.90380
# [743]	validation_0-mlogloss:1.90377
# [744]	validation_0-mlogloss:1.90375
# [745]	validation_0-mlogloss:1.90373
# [746]	validation_0-mlogloss:1.90371
# [747]	validation_0-mlogloss:1.90368
# [748]	validation_0-mlogloss:1.90366
# [749]	validation_0-mlogloss:1.90364
# [750]	validation_0-mlogloss:1.90361
# [751]	validation_0-mlogloss:1.90359
# [752]	validation_0-mlogloss:1.90356
# [753]	validation_0-mlogloss:1.90354
# [754]	validation_0-mlogloss:1.90351
# [755]	validation_0-mlogloss:1.90350
# [756]	validation_0-mlogloss:1.90347
# [757]	validation_0-mlogloss:1.90345
# [758]	validation_0-mlogloss:1.90343
# [759]	validation_0-mlogloss:1.90340
# [760]	validation_0-mlogloss:1.90339
# [761]	validation_0-mlogloss:1.90336
# [762]	validation_0-mlogloss:1.90334
# [763]	validation_0-mlogloss:1.90333
# [764]	validation_0-mlogloss:1.90330
# [765]	validation_0-mlogloss:1.90328
# [766]	validation_0-mlogloss:1.90325
# [767]	validation_0-mlogloss:1.90324
# [768]	validation_0-mlogloss:1.90322
# [769]	validation_0-mlogloss:1.90318
# [770]	validation_0-mlogloss:1.90316
# [771]	validation_0-mlogloss:1.90314
# [772]	validation_0-mlogloss:1.90311
# [773]	validation_0-mlogloss:1.90309
# [774]	validation_0-mlogloss:1.90307
# [775]	validation_0-mlogloss:1.90305
# [776]	validation_0-mlogloss:1.90302
# [777]	validation_0-mlogloss:1.90299
# [778]	validation_0-mlogloss:1.90297
# [779]	validation_0-mlogloss:1.90295
# [780]	validation_0-mlogloss:1.90292
# [781]	validation_0-mlogloss:1.90290
# [782]	validation_0-mlogloss:1.90287
# [783]	validation_0-mlogloss:1.90285
# [784]	validation_0-mlogloss:1.90283
# [785]	validation_0-mlogloss:1.90280
# [786]	validation_0-mlogloss:1.90279
# [787]	validation_0-mlogloss:1.90277
# [788]	validation_0-mlogloss:1.90274
# [789]	validation_0-mlogloss:1.90273
# [790]	validation_0-mlogloss:1.90270
# [791]	validation_0-mlogloss:1.90268
# [792]	validation_0-mlogloss:1.90265
# [793]	validation_0-mlogloss:1.90262
# [794]	validation_0-mlogloss:1.90261
# [795]	validation_0-mlogloss:1.90259
# [796]	validation_0-mlogloss:1.90257
# [797]	validation_0-mlogloss:1.90254
# [798]	validation_0-mlogloss:1.90252
# [799]	validation_0-mlogloss:1.90250
# [800]	validation_0-mlogloss:1.90248
# [801]	validation_0-mlogloss:1.90246
# [802]	validation_0-mlogloss:1.90243
# [803]	validation_0-mlogloss:1.90240
# [804]	validation_0-mlogloss:1.90237
# [805]	validation_0-mlogloss:1.90235
# [806]	validation_0-mlogloss:1.90233
# [807]	validation_0-mlogloss:1.90230
# [808]	validation_0-mlogloss:1.90228
# [809]	validation_0-mlogloss:1.90226
# [810]	validation_0-mlogloss:1.90225
# [811]	validation_0-mlogloss:1.90223
# [812]	validation_0-mlogloss:1.90221
# [813]	validation_0-mlogloss:1.90219
# [814]	validation_0-mlogloss:1.90216
# [815]	validation_0-mlogloss:1.90213
# [816]	validation_0-mlogloss:1.90211
# [817]	validation_0-mlogloss:1.90209
# [818]	validation_0-mlogloss:1.90207
# [819]	validation_0-mlogloss:1.90204
# [820]	validation_0-mlogloss:1.90202
# [821]	validation_0-mlogloss:1.90200
# [822]	validation_0-mlogloss:1.90198
# [823]	validation_0-mlogloss:1.90196
# [824]	validation_0-mlogloss:1.90192
# [825]	validation_0-mlogloss:1.90190
# [826]	validation_0-mlogloss:1.90188
# [827]	validation_0-mlogloss:1.90186
# [828]	validation_0-mlogloss:1.90184
# [829]	validation_0-mlogloss:1.90182
# [830]	validation_0-mlogloss:1.90179
# [831]	validation_0-mlogloss:1.90178
# [832]	validation_0-mlogloss:1.90173
# [833]	validation_0-mlogloss:1.90171
# [834]	validation_0-mlogloss:1.90169
# [835]	validation_0-mlogloss:1.90166
# [836]	validation_0-mlogloss:1.90163
# [837]	validation_0-mlogloss:1.90162
# [838]	validation_0-mlogloss:1.90158
# [839]	validation_0-mlogloss:1.90156
# [840]	validation_0-mlogloss:1.90153
# [841]	validation_0-mlogloss:1.90151
# [842]	validation_0-mlogloss:1.90149
# [843]	validation_0-mlogloss:1.90148
# [844]	validation_0-mlogloss:1.90146
# [845]	validation_0-mlogloss:1.90144
# [846]	validation_0-mlogloss:1.90142
# [847]	validation_0-mlogloss:1.90139
# [848]	validation_0-mlogloss:1.90138
# [849]	validation_0-mlogloss:1.90135
# [850]	validation_0-mlogloss:1.90133
# [851]	validation_0-mlogloss:1.90130
# [852]	validation_0-mlogloss:1.90129
# [853]	validation_0-mlogloss:1.90126
# [854]	validation_0-mlogloss:1.90123
# [855]	validation_0-mlogloss:1.90121
# [856]	validation_0-mlogloss:1.90119
# [857]	validation_0-mlogloss:1.90117
# [858]	validation_0-mlogloss:1.90114
# [859]	validation_0-mlogloss:1.90112
# [860]	validation_0-mlogloss:1.90110
# [861]	validation_0-mlogloss:1.90108
# [862]	validation_0-mlogloss:1.90105
# [863]	validation_0-mlogloss:1.90103
# [864]	validation_0-mlogloss:1.90101
# [865]	validation_0-mlogloss:1.90098
# [866]	validation_0-mlogloss:1.90097
# [867]	validation_0-mlogloss:1.90094
# [868]	validation_0-mlogloss:1.90092
# [869]	validation_0-mlogloss:1.90090
# [870]	validation_0-mlogloss:1.90087
# [871]	validation_0-mlogloss:1.90085
# [872]	validation_0-mlogloss:1.90083
# [873]	validation_0-mlogloss:1.90082
# [874]	validation_0-mlogloss:1.90080
# [875]	validation_0-mlogloss:1.90078
# [876]	validation_0-mlogloss:1.90076
# [877]	validation_0-mlogloss:1.90074
# [878]	validation_0-mlogloss:1.90072
# [879]	validation_0-mlogloss:1.90070
# [880]	validation_0-mlogloss:1.90068
# [881]	validation_0-mlogloss:1.90066
# [882]	validation_0-mlogloss:1.90064
# [883]	validation_0-mlogloss:1.90062
# [884]	validation_0-mlogloss:1.90059
# [885]	validation_0-mlogloss:1.90057
# [886]	validation_0-mlogloss:1.90055
# [887]	validation_0-mlogloss:1.90054
# [888]	validation_0-mlogloss:1.90051
# [889]	validation_0-mlogloss:1.90049
# [890]	validation_0-mlogloss:1.90046
# [891]	validation_0-mlogloss:1.90045
# [892]	validation_0-mlogloss:1.90042
# [893]	validation_0-mlogloss:1.90041
# [894]	validation_0-mlogloss:1.90039
# [895]	validation_0-mlogloss:1.90038
# [896]	validation_0-mlogloss:1.90037
# [897]	validation_0-mlogloss:1.90035
# [898]	validation_0-mlogloss:1.90034
# [899]	validation_0-mlogloss:1.90032
# [900]	validation_0-mlogloss:1.90030
# [901]	validation_0-mlogloss:1.90029
# [902]	validation_0-mlogloss:1.90027
# [903]	validation_0-mlogloss:1.90025
# [904]	validation_0-mlogloss:1.90023
# [905]	validation_0-mlogloss:1.90021
# [906]	validation_0-mlogloss:1.90020
# [907]	validation_0-mlogloss:1.90019
# [908]	validation_0-mlogloss:1.90017
# [909]	validation_0-mlogloss:1.90015
# [910]	validation_0-mlogloss:1.90013
# [911]	validation_0-mlogloss:1.90011
# [912]	validation_0-mlogloss:1.90009
# [913]	validation_0-mlogloss:1.90006
# [914]	validation_0-mlogloss:1.90003
# [915]	validation_0-mlogloss:1.90001
# [916]	validation_0-mlogloss:1.89999
# [917]	validation_0-mlogloss:1.89998
# [918]	validation_0-mlogloss:1.89995
# [919]	validation_0-mlogloss:1.89994
# [920]	validation_0-mlogloss:1.89993
# [921]	validation_0-mlogloss:1.89990
# [922]	validation_0-mlogloss:1.89989
# [923]	validation_0-mlogloss:1.89986
# [924]	validation_0-mlogloss:1.89983
# [925]	validation_0-mlogloss:1.89980
# [926]	validation_0-mlogloss:1.89979
# [927]	validation_0-mlogloss:1.89977
# [928]	validation_0-mlogloss:1.89975
# [929]	validation_0-mlogloss:1.89973
# [930]	validation_0-mlogloss:1.89972
# [931]	validation_0-mlogloss:1.89970
# [932]	validation_0-mlogloss:1.89969
# [933]	validation_0-mlogloss:1.89966
# [934]	validation_0-mlogloss:1.89964
# [935]	validation_0-mlogloss:1.89962
# [936]	validation_0-mlogloss:1.89961
# [937]	validation_0-mlogloss:1.89959
# [938]	validation_0-mlogloss:1.89957
# [939]	validation_0-mlogloss:1.89956
# [940]	validation_0-mlogloss:1.89954
# [941]	validation_0-mlogloss:1.89953
# [942]	validation_0-mlogloss:1.89951
# [943]	validation_0-mlogloss:1.89949
# [944]	validation_0-mlogloss:1.89948
# [945]	validation_0-mlogloss:1.89946
# [946]	validation_0-mlogloss:1.89945
# [947]	validation_0-mlogloss:1.89943
# [948]	validation_0-mlogloss:1.89941
# [949]	validation_0-mlogloss:1.89938
# [950]	validation_0-mlogloss:1.89937
# [951]	validation_0-mlogloss:1.89935
# [952]	validation_0-mlogloss:1.89933
# [953]	validation_0-mlogloss:1.89932
# [954]	validation_0-mlogloss:1.89929
# [955]	validation_0-mlogloss:1.89929
# [956]	validation_0-mlogloss:1.89927
# [957]	validation_0-mlogloss:1.89925
# [958]	validation_0-mlogloss:1.89923
# [959]	validation_0-mlogloss:1.89922
# [960]	validation_0-mlogloss:1.89920
# [961]	validation_0-mlogloss:1.89917
# [962]	validation_0-mlogloss:1.89915
# [963]	validation_0-mlogloss:1.89914
# [964]	validation_0-mlogloss:1.89913
# [965]	validation_0-mlogloss:1.89912
# [966]	validation_0-mlogloss:1.89910
# [967]	validation_0-mlogloss:1.89908
# [968]	validation_0-mlogloss:1.89906
# [969]	validation_0-mlogloss:1.89904
# [970]	validation_0-mlogloss:1.89902
# [971]	validation_0-mlogloss:1.89901
# [972]	validation_0-mlogloss:1.89899
# [973]	validation_0-mlogloss:1.89896
# [974]	validation_0-mlogloss:1.89894
# [975]	validation_0-mlogloss:1.89893
# [976]	validation_0-mlogloss:1.89891
# [977]	validation_0-mlogloss:1.89889
# [978]	validation_0-mlogloss:1.89888
# [979]	validation_0-mlogloss:1.89886
# [980]	validation_0-mlogloss:1.89886
# [981]	validation_0-mlogloss:1.89884
# [982]	validation_0-mlogloss:1.89882
# [983]	validation_0-mlogloss:1.89881
# [984]	validation_0-mlogloss:1.89879
# [985]	validation_0-mlogloss:1.89877
# [986]	validation_0-mlogloss:1.89875
# [987]	validation_0-mlogloss:1.89873
# [988]	validation_0-mlogloss:1.89872
# [989]	validation_0-mlogloss:1.89870
# [990]	validation_0-mlogloss:1.89868
# [991]	validation_0-mlogloss:1.89866
# [992]	validation_0-mlogloss:1.89864
# [993]	validation_0-mlogloss:1.89863
# [994]	validation_0-mlogloss:1.89863
# [995]	validation_0-mlogloss:1.89861
# [996]	validation_0-mlogloss:1.89859
# [997]	validation_0-mlogloss:1.89857
# [998]	validation_0-mlogloss:1.89856
# [999]	validation_0-mlogloss:1.89854
# [1000]	validation_0-mlogloss:1.89853
# [1001]	validation_0-mlogloss:1.89850
# [1002]	validation_0-mlogloss:1.89849
# [1003]	validation_0-mlogloss:1.89848
# [1004]	validation_0-mlogloss:1.89846
# [1005]	validation_0-mlogloss:1.89843
# [1006]	validation_0-mlogloss:1.89841
# [1007]	validation_0-mlogloss:1.89839
# [1008]	validation_0-mlogloss:1.89837
# [1009]	validation_0-mlogloss:1.89836
# [1010]	validation_0-mlogloss:1.89835
# [1011]	validation_0-mlogloss:1.89833
# [1012]	validation_0-mlogloss:1.89831
# [1013]	validation_0-mlogloss:1.89828
# [1014]	validation_0-mlogloss:1.89827
# [1015]	validation_0-mlogloss:1.89825
# [1016]	validation_0-mlogloss:1.89824
# [1017]	validation_0-mlogloss:1.89823
# [1018]	validation_0-mlogloss:1.89821
# [1019]	validation_0-mlogloss:1.89818
# [1020]	validation_0-mlogloss:1.89816
# [1021]	validation_0-mlogloss:1.89815
# [1022]	validation_0-mlogloss:1.89814
# [1023]	validation_0-mlogloss:1.89811
# [1024]	validation_0-mlogloss:1.89811
# [1025]	validation_0-mlogloss:1.89810
# [1026]	validation_0-mlogloss:1.89808
# [1027]	validation_0-mlogloss:1.89806
# [1028]	validation_0-mlogloss:1.89804
# [1029]	validation_0-mlogloss:1.89802
# [1030]	validation_0-mlogloss:1.89800
# [1031]	validation_0-mlogloss:1.89799
# [1032]	validation_0-mlogloss:1.89798
# [1033]	validation_0-mlogloss:1.89795
# [1034]	validation_0-mlogloss:1.89793
# [1035]	validation_0-mlogloss:1.89791
# [1036]	validation_0-mlogloss:1.89790
# [1037]	validation_0-mlogloss:1.89789
# [1038]	validation_0-mlogloss:1.89786
# [1039]	validation_0-mlogloss:1.89784
# [1040]	validation_0-mlogloss:1.89783
# [1041]	validation_0-mlogloss:1.89781
# [1042]	validation_0-mlogloss:1.89779
# [1043]	validation_0-mlogloss:1.89777
# [1044]	validation_0-mlogloss:1.89775
# [1045]	validation_0-mlogloss:1.89774
# [1046]	validation_0-mlogloss:1.89772
# [1047]	validation_0-mlogloss:1.89771
# [1048]	validation_0-mlogloss:1.89769
# [1049]	validation_0-mlogloss:1.89768
# [1050]	validation_0-mlogloss:1.89766
# [1051]	validation_0-mlogloss:1.89764
# [1052]	validation_0-mlogloss:1.89763
# [1053]	validation_0-mlogloss:1.89761
# [1054]	validation_0-mlogloss:1.89760
# [1055]	validation_0-mlogloss:1.89759
# [1056]	validation_0-mlogloss:1.89757
# [1057]	validation_0-mlogloss:1.89756
# [1058]	validation_0-mlogloss:1.89753
# [1059]	validation_0-mlogloss:1.89752
# [1060]	validation_0-mlogloss:1.89750
# [1061]	validation_0-mlogloss:1.89748
# [1062]	validation_0-mlogloss:1.89746
# [1063]	validation_0-mlogloss:1.89745
# [1064]	validation_0-mlogloss:1.89743
# [1065]	validation_0-mlogloss:1.89741
# [1066]	validation_0-mlogloss:1.89739
# [1067]	validation_0-mlogloss:1.89738
# [1068]	validation_0-mlogloss:1.89735
# [1069]	validation_0-mlogloss:1.89734
# [1070]	validation_0-mlogloss:1.89732
# [1071]	validation_0-mlogloss:1.89731
# [1072]	validation_0-mlogloss:1.89729
# [1073]	validation_0-mlogloss:1.89727
# [1074]	validation_0-mlogloss:1.89726
# [1075]	validation_0-mlogloss:1.89726
# [1076]	validation_0-mlogloss:1.89725
# [1077]	validation_0-mlogloss:1.89723
# [1078]	validation_0-mlogloss:1.89723
# [1079]	validation_0-mlogloss:1.89721
# [1080]	validation_0-mlogloss:1.89720
# [1081]	validation_0-mlogloss:1.89719
# [1082]	validation_0-mlogloss:1.89718
# [1083]	validation_0-mlogloss:1.89716
# [1084]	validation_0-mlogloss:1.89715
# [1085]	validation_0-mlogloss:1.89712
# [1086]	validation_0-mlogloss:1.89711
# [1087]	validation_0-mlogloss:1.89709
# [1088]	validation_0-mlogloss:1.89707
# [1089]	validation_0-mlogloss:1.89706
# [1090]	validation_0-mlogloss:1.89704
# [1091]	validation_0-mlogloss:1.89703
# [1092]	validation_0-mlogloss:1.89701
# [1093]	validation_0-mlogloss:1.89699
# [1094]	validation_0-mlogloss:1.89698
# [1095]	validation_0-mlogloss:1.89696
# [1096]	validation_0-mlogloss:1.89695
# [1097]	validation_0-mlogloss:1.89694
# [1098]	validation_0-mlogloss:1.89692
# [1099]	validation_0-mlogloss:1.89690
# [1100]	validation_0-mlogloss:1.89689
# [1101]	validation_0-mlogloss:1.89687
# [1102]	validation_0-mlogloss:1.89686
# [1103]	validation_0-mlogloss:1.89684
# [1104]	validation_0-mlogloss:1.89683
# [1105]	validation_0-mlogloss:1.89681
# [1106]	validation_0-mlogloss:1.89680
# [1107]	validation_0-mlogloss:1.89678
# [1108]	validation_0-mlogloss:1.89676
# [1109]	validation_0-mlogloss:1.89674
# [1110]	validation_0-mlogloss:1.89673
# [1111]	validation_0-mlogloss:1.89671
# [1112]	validation_0-mlogloss:1.89670
# [1113]	validation_0-mlogloss:1.89669
# [1114]	validation_0-mlogloss:1.89667
# [1115]	validation_0-mlogloss:1.89667
# [1116]	validation_0-mlogloss:1.89666
# [1117]	validation_0-mlogloss:1.89665
# [1118]	validation_0-mlogloss:1.89663
# [1119]	validation_0-mlogloss:1.89662
# [1120]	validation_0-mlogloss:1.89661
# [1121]	validation_0-mlogloss:1.89660
# [1122]	validation_0-mlogloss:1.89659
# [1123]	validation_0-mlogloss:1.89657
# [1124]	validation_0-mlogloss:1.89656
# [1125]	validation_0-mlogloss:1.89654
# [1126]	validation_0-mlogloss:1.89652
# [1127]	validation_0-mlogloss:1.89651
# [1128]	validation_0-mlogloss:1.89650
# [1129]	validation_0-mlogloss:1.89649
# [1130]	validation_0-mlogloss:1.89646
# [1131]	validation_0-mlogloss:1.89645
# [1132]	validation_0-mlogloss:1.89644
# [1133]	validation_0-mlogloss:1.89642
# [1134]	validation_0-mlogloss:1.89641
# [1135]	validation_0-mlogloss:1.89640
# [1136]	validation_0-mlogloss:1.89639
# [1137]	validation_0-mlogloss:1.89637
# [1138]	validation_0-mlogloss:1.89635
# [1139]	validation_0-mlogloss:1.89633
# [1140]	validation_0-mlogloss:1.89632
# [1141]	validation_0-mlogloss:1.89630
# [1142]	validation_0-mlogloss:1.89629
# [1143]	validation_0-mlogloss:1.89627
# [1144]	validation_0-mlogloss:1.89626
# [1145]	validation_0-mlogloss:1.89625
# [1146]	validation_0-mlogloss:1.89623
# [1147]	validation_0-mlogloss:1.89622
# [1148]	validation_0-mlogloss:1.89620
# [1149]	validation_0-mlogloss:1.89619
# [1150]	validation_0-mlogloss:1.89618
# [1151]	validation_0-mlogloss:1.89617
# [1152]	validation_0-mlogloss:1.89615
# [1153]	validation_0-mlogloss:1.89613
# [1154]	validation_0-mlogloss:1.89611
# [1155]	validation_0-mlogloss:1.89608
# [1156]	validation_0-mlogloss:1.89606
# [1157]	validation_0-mlogloss:1.89605
# [1158]	validation_0-mlogloss:1.89603
# [1159]	validation_0-mlogloss:1.89601
# [1160]	validation_0-mlogloss:1.89600
# [1161]	validation_0-mlogloss:1.89599
# [1162]	validation_0-mlogloss:1.89598
# [1163]	validation_0-mlogloss:1.89597
# [1164]	validation_0-mlogloss:1.89595
# [1165]	validation_0-mlogloss:1.89594
# [1166]	validation_0-mlogloss:1.89593
# [1167]	validation_0-mlogloss:1.89592
# [1168]	validation_0-mlogloss:1.89590
# [1169]	validation_0-mlogloss:1.89588
# [1170]	validation_0-mlogloss:1.89587
# [1171]	validation_0-mlogloss:1.89584
# [1172]	validation_0-mlogloss:1.89583
# [1173]	validation_0-mlogloss:1.89582
# [1174]	validation_0-mlogloss:1.89580
# [1175]	validation_0-mlogloss:1.89578
# [1176]	validation_0-mlogloss:1.89577
# [1177]	validation_0-mlogloss:1.89576
# [1178]	validation_0-mlogloss:1.89574
# [1179]	validation_0-mlogloss:1.89573
# [1180]	validation_0-mlogloss:1.89571
# [1181]	validation_0-mlogloss:1.89570
# [1182]	validation_0-mlogloss:1.89568
# [1183]	validation_0-mlogloss:1.89567
# [1184]	validation_0-mlogloss:1.89566
# [1185]	validation_0-mlogloss:1.89565
# [1186]	validation_0-mlogloss:1.89564
# [1187]	validation_0-mlogloss:1.89563
# [1188]	validation_0-mlogloss:1.89561
# [1189]	validation_0-mlogloss:1.89559
# [1190]	validation_0-mlogloss:1.89557
# [1191]	validation_0-mlogloss:1.89555
# [1192]	validation_0-mlogloss:1.89554
# [1193]	validation_0-mlogloss:1.89552
# [1194]	validation_0-mlogloss:1.89551
# [1195]	validation_0-mlogloss:1.89549
# [1196]	validation_0-mlogloss:1.89547
# [1197]	validation_0-mlogloss:1.89546
# [1198]	validation_0-mlogloss:1.89545
# [1199]	validation_0-mlogloss:1.89544
# [1200]	validation_0-mlogloss:1.89543
# [1201]	validation_0-mlogloss:1.89541
# [1202]	validation_0-mlogloss:1.89539
# [1203]	validation_0-mlogloss:1.89537
# [1204]	validation_0-mlogloss:1.89536
# [1205]	validation_0-mlogloss:1.89535
# [1206]	validation_0-mlogloss:1.89534
# [1207]	validation_0-mlogloss:1.89533
# [1208]	validation_0-mlogloss:1.89531
# [1209]	validation_0-mlogloss:1.89530
# [1210]	validation_0-mlogloss:1.89528
# [1211]	validation_0-mlogloss:1.89526
# [1212]	validation_0-mlogloss:1.89525
# [1213]	validation_0-mlogloss:1.89524
# [1214]	validation_0-mlogloss:1.89523
# [1215]	validation_0-mlogloss:1.89521
# [1216]	validation_0-mlogloss:1.89520
# [1217]	validation_0-mlogloss:1.89518
# [1218]	validation_0-mlogloss:1.89516
# [1219]	validation_0-mlogloss:1.89514
# [1220]	validation_0-mlogloss:1.89512
# [1221]	validation_0-mlogloss:1.89511
# [1222]	validation_0-mlogloss:1.89510
# [1223]	validation_0-mlogloss:1.89509
# [1224]	validation_0-mlogloss:1.89507
# [1225]	validation_0-mlogloss:1.89505
# [1226]	validation_0-mlogloss:1.89504
# [1227]	validation_0-mlogloss:1.89503
# [1228]	validation_0-mlogloss:1.89502
# [1229]	validation_0-mlogloss:1.89500
# [1230]	validation_0-mlogloss:1.89499
# [1231]	validation_0-mlogloss:1.89497
# [1232]	validation_0-mlogloss:1.89496
# [1233]	validation_0-mlogloss:1.89494
# [1234]	validation_0-mlogloss:1.89493
# [1235]	validation_0-mlogloss:1.89491
# [1236]	validation_0-mlogloss:1.89490
# [1237]	validation_0-mlogloss:1.89489
# [1238]	validation_0-mlogloss:1.89487
# [1239]	validation_0-mlogloss:1.89486
# [1240]	validation_0-mlogloss:1.89485
# [1241]	validation_0-mlogloss:1.89484
# [1242]	validation_0-mlogloss:1.89483
# [1243]	validation_0-mlogloss:1.89482
# [1244]	validation_0-mlogloss:1.89480
# [1245]	validation_0-mlogloss:1.89480
# [1246]	validation_0-mlogloss:1.89479
# [1247]	validation_0-mlogloss:1.89477
# [1248]	validation_0-mlogloss:1.89475
# [1249]	validation_0-mlogloss:1.89473
# [1250]	validation_0-mlogloss:1.89472
# [1251]	validation_0-mlogloss:1.89470
# [1252]	validation_0-mlogloss:1.89469
# [1253]	validation_0-mlogloss:1.89468
# [1254]	validation_0-mlogloss:1.89466
# [1255]	validation_0-mlogloss:1.89465
# [1256]	validation_0-mlogloss:1.89464
# [1257]	validation_0-mlogloss:1.89463
# [1258]	validation_0-mlogloss:1.89462
# [1259]	validation_0-mlogloss:1.89461
# [1260]	validation_0-mlogloss:1.89459
# [1261]	validation_0-mlogloss:1.89458
# [1262]	validation_0-mlogloss:1.89456
# [1263]	validation_0-mlogloss:1.89455
# [1264]	validation_0-mlogloss:1.89453
# [1265]	validation_0-mlogloss:1.89452
# [1266]	validation_0-mlogloss:1.89452
# [1267]	validation_0-mlogloss:1.89450
# [1268]	validation_0-mlogloss:1.89449
# [1269]	validation_0-mlogloss:1.89448
# [1270]	validation_0-mlogloss:1.89447
# [1271]	validation_0-mlogloss:1.89446
# [1272]	validation_0-mlogloss:1.89445
# [1273]	validation_0-mlogloss:1.89445
# [1274]	validation_0-mlogloss:1.89444
# [1275]	validation_0-mlogloss:1.89442
# [1276]	validation_0-mlogloss:1.89442
# [1277]	validation_0-mlogloss:1.89441
# [1278]	validation_0-mlogloss:1.89440
# [1279]	validation_0-mlogloss:1.89439
# [1280]	validation_0-mlogloss:1.89437
# [1281]	validation_0-mlogloss:1.89436
# [1282]	validation_0-mlogloss:1.89435
# [1283]	validation_0-mlogloss:1.89434
# [1284]	validation_0-mlogloss:1.89433
# [1285]	validation_0-mlogloss:1.89431
# [1286]	validation_0-mlogloss:1.89430
# [1287]	validation_0-mlogloss:1.89429
# [1288]	validation_0-mlogloss:1.89427
# [1289]	validation_0-mlogloss:1.89426
# [1290]	validation_0-mlogloss:1.89424
# [1291]	validation_0-mlogloss:1.89422
# [1292]	validation_0-mlogloss:1.89422
# [1293]	validation_0-mlogloss:1.89421
# [1294]	validation_0-mlogloss:1.89420
# [1295]	validation_0-mlogloss:1.89419
# [1296]	validation_0-mlogloss:1.89418
# [1297]	validation_0-mlogloss:1.89417
# [1298]	validation_0-mlogloss:1.89416
# [1299]	validation_0-mlogloss:1.89415
# [1300]	validation_0-mlogloss:1.89413
# [1301]	validation_0-mlogloss:1.89413
# [1302]	validation_0-mlogloss:1.89412
# [1303]	validation_0-mlogloss:1.89411
# [1304]	validation_0-mlogloss:1.89410
# [1305]	validation_0-mlogloss:1.89408
# [1306]	validation_0-mlogloss:1.89407
# [1307]	validation_0-mlogloss:1.89405
# [1308]	validation_0-mlogloss:1.89405
# [1309]	validation_0-mlogloss:1.89403
# [1310]	validation_0-mlogloss:1.89401
# [1311]	validation_0-mlogloss:1.89400
# [1312]	validation_0-mlogloss:1.89399
# [1313]	validation_0-mlogloss:1.89398
# [1314]	validation_0-mlogloss:1.89396
# [1315]	validation_0-mlogloss:1.89395
# [1316]	validation_0-mlogloss:1.89393
# [1317]	validation_0-mlogloss:1.89392
# [1318]	validation_0-mlogloss:1.89391
# [1319]	validation_0-mlogloss:1.89390
# [1320]	validation_0-mlogloss:1.89389
# [1321]	validation_0-mlogloss:1.89387
# [1322]	validation_0-mlogloss:1.89386
# [1323]	validation_0-mlogloss:1.89384
# [1324]	validation_0-mlogloss:1.89383
# [1325]	validation_0-mlogloss:1.89381
# [1326]	validation_0-mlogloss:1.89380
# ...
# [2945]	validation_0-mlogloss:1.88333
# [2946]	validation_0-mlogloss:1.88333
# [2947]	validation_0-mlogloss:1.88333
# [2948]	validation_0-mlogloss:1.88332
# [2949]	validation_0-mlogloss:1.88332
# [2950]	validation_0-mlogloss:1.88331
# [2951]	validation_0-mlogloss:1.88331
# [2952]	validation_0-mlogloss:1.88331
# [2953]	validation_0-mlogloss:1.88330
# [2954]	validation_0-mlogloss:1.88330
# [2955]	validation_0-mlogloss:1.88330
# [2956]	validation_0-mlogloss:1.88330
# [2957]	validation_0-mlogloss:1.88329
# [2958]	validation_0-mlogloss:1.88329
# [2959]	validation_0-mlogloss:1.88329
# [2960]	validation_0-mlogloss:1.88328
# [2961]	validation_0-mlogloss:1.88328
# [2962]	validation_0-mlogloss:1.88328
# [2963]	validation_0-mlogloss:1.88328
# [2964]	validation_0-mlogloss:1.88328
# [2965]	validation_0-mlogloss:1.88328
# [2966]	validation_0-mlogloss:1.88328
# [2967]	validation_0-mlogloss:1.88328
# [2968]	validation_0-mlogloss:1.88328
# [2969]	validation_0-mlogloss:1.88328
# [2970]	validation_0-mlogloss:1.88328
# [2971]	validation_0-mlogloss:1.88327
# [2972]	validation_0-mlogloss:1.88327
# [2973]	validation_0-mlogloss:1.88327
# [2974]	validation_0-mlogloss:1.88327
# [2975]	validation_0-mlogloss:1.88327
# [2976]	validation_0-mlogloss:1.88327
# [2977]	validation_0-mlogloss:1.88327
# [2978]	validation_0-mlogloss:1.88327
# [2979]	validation_0-mlogloss:1.88327
# [2980]	validation_0-mlogloss:1.88327
# [2981]	validation_0-mlogloss:1.88327
# [2982]	validation_0-mlogloss:1.88326
# [2983]	validation_0-mlogloss:1.88326
# [2984]	validation_0-mlogloss:1.88326
# [2985]	validation_0-mlogloss:1.88325
# [2986]	validation_0-mlogloss:1.88325
# [2987]	validation_0-mlogloss:1.88324
# [2988]	validation_0-mlogloss:1.88324
# [2989]	validation_0-mlogloss:1.88324
# [2990]	validation_0-mlogloss:1.88323
# [2991]	validation_0-mlogloss:1.88323
# [2992]	validation_0-mlogloss:1.88322
# [2993]	validation_0-mlogloss:1.88322
# [2994]	validation_0-mlogloss:1.88322
# [2995]	validation_0-mlogloss:1.88322
# [2996]	validation_0-mlogloss:1.88322
# [2997]	validation_0-mlogloss:1.88321
# [2998]	validation_0-mlogloss:1.88321
# [2999]	validation_0-mlogloss:1.88320
# [3000]	validation_0-mlogloss:1.88320
# [3001]	validation_0-mlogloss:1.88320
# [3002]	validation_0-mlogloss:1.88319
# [3003]	validation_0-mlogloss:1.88319
# [3004]	validation_0-mlogloss:1.88318
# [3005]	validation_0-mlogloss:1.88318
# [3006]	validation_0-mlogloss:1.88318
# [3007]	validation_0-mlogloss:1.88317
# [3008]	validation_0-mlogloss:1.88317
# [3009]	validation_0-mlogloss:1.88317
# [3010]	validation_0-mlogloss:1.88317
# [3011]	validation_0-mlogloss:1.88317
# [3012]	validation_0-mlogloss:1.88316
# [3013]	validation_0-mlogloss:1.88316
# [3014]	validation_0-mlogloss:1.88316
# [3015]	validation_0-mlogloss:1.88315
# [3016]	validation_0-mlogloss:1.88315
# [3017]	validation_0-mlogloss:1.88315
# [3018]	validation_0-mlogloss:1.88314
# [3019]	validation_0-mlogloss:1.88314
# [3020]	validation_0-mlogloss:1.88314
# [3021]	validation_0-mlogloss:1.88314
# [3022]	validation_0-mlogloss:1.88314
# [3023]	validation_0-mlogloss:1.88314
# [3024]	validation_0-mlogloss:1.88314
# [3025]	validation_0-mlogloss:1.88314
# [3026]	validation_0-mlogloss:1.88314
# [3027]	validation_0-mlogloss:1.88314
# [3028]	validation_0-mlogloss:1.88313
# [3029]	validation_0-mlogloss:1.88313
# [3030]	validation_0-mlogloss:1.88313
# [3031]	validation_0-mlogloss:1.88313
# [3032]	validation_0-mlogloss:1.88313
# [3033]	validation_0-mlogloss:1.88312
# [3034]	validation_0-mlogloss:1.88312
# [3035]	validation_0-mlogloss:1.88312
# [3036]	validation_0-mlogloss:1.88311
# [3037]	validation_0-mlogloss:1.88311
# [3038]	validation_0-mlogloss:1.88311
# [3039]	validation_0-mlogloss:1.88310
# [3040]	validation_0-mlogloss:1.88310
# [3041]	validation_0-mlogloss:1.88310
# [3042]	validation_0-mlogloss:1.88310
# [3043]	validation_0-mlogloss:1.88310
# [3044]	validation_0-mlogloss:1.88310
# [3045]	validation_0-mlogloss:1.88310
# [3046]	validation_0-mlogloss:1.88310
# [3047]	validation_0-mlogloss:1.88310
# [3048]	validation_0-mlogloss:1.88309
# [3049]	validation_0-mlogloss:1.88309
# [3050]	validation_0-mlogloss:1.88309
# [3051]	validation_0-mlogloss:1.88309
# [3052]	validation_0-mlogloss:1.88309
# [3053]	validation_0-mlogloss:1.88309
# [3054]	validation_0-mlogloss:1.88309
# [3055]	validation_0-mlogloss:1.88309
# [3056]	validation_0-mlogloss:1.88308
# [3057]	validation_0-mlogloss:1.88308
# [3058]	validation_0-mlogloss:1.88308
# [3059]	validation_0-mlogloss:1.88308
# [3060]	validation_0-mlogloss:1.88307
# [3061]	validation_0-mlogloss:1.88307
# [3062]	validation_0-mlogloss:1.88307
# [3063]	validation_0-mlogloss:1.88307
# [3064]	validation_0-mlogloss:1.88306
# [3065]	validation_0-mlogloss:1.88306
# [3066]	validation_0-mlogloss:1.88306
# [3067]	validation_0-mlogloss:1.88306
# [3068]	validation_0-mlogloss:1.88306
# [3069]	validation_0-mlogloss:1.88306
# [3070]	validation_0-mlogloss:1.88305
# [3071]	validation_0-mlogloss:1.88305
# [3072]	validation_0-mlogloss:1.88305
# [3073]	validation_0-mlogloss:1.88305
# [3074]	validation_0-mlogloss:1.88305
# [3075]	validation_0-mlogloss:1.88304
# [3076]	validation_0-mlogloss:1.88304
# [3077]	validation_0-mlogloss:1.88304
# [3078]	validation_0-mlogloss:1.88303
# [3079]	validation_0-mlogloss:1.88303
# [3080]	validation_0-mlogloss:1.88303
# [3081]	validation_0-mlogloss:1.88303
# [3082]	validation_0-mlogloss:1.88303
# [3083]	validation_0-mlogloss:1.88303
# [3084]	validation_0-mlogloss:1.88303
# [3085]	validation_0-mlogloss:1.88303
# [3086]	validation_0-mlogloss:1.88302
# [3087]	validation_0-mlogloss:1.88302
# [3088]	validation_0-mlogloss:1.88302
# [3089]	validation_0-mlogloss:1.88302
# [3090]	validation_0-mlogloss:1.88302
# [3091]	validation_0-mlogloss:1.88302
# [3092]	validation_0-mlogloss:1.88301
# [3093]	validation_0-mlogloss:1.88301
# [3094]	validation_0-mlogloss:1.88300
# [3095]	validation_0-mlogloss:1.88300
# [3096]	validation_0-mlogloss:1.88300
# [3097]	validation_0-mlogloss:1.88300
# [3098]	validation_0-mlogloss:1.88300
# [3099]	validation_0-mlogloss:1.88300
# [3100]	validation_0-mlogloss:1.88300
# [3101]	validation_0-mlogloss:1.88300
# [3102]	validation_0-mlogloss:1.88299
# [3103]	validation_0-mlogloss:1.88299
# [3104]	validation_0-mlogloss:1.88299
# [3105]	validation_0-mlogloss:1.88298
# [3106]	validation_0-mlogloss:1.88298
# [3107]	validation_0-mlogloss:1.88298
# [3108]	validation_0-mlogloss:1.88298
# [3109]	validation_0-mlogloss:1.88298
# [3110]	validation_0-mlogloss:1.88298
# [3111]	validation_0-mlogloss:1.88298
# [3112]	validation_0-mlogloss:1.88297
# [3113]	validation_0-mlogloss:1.88297
# [3114]	validation_0-mlogloss:1.88297
# [3115]	validation_0-mlogloss:1.88297
# [3116]	validation_0-mlogloss:1.88296
# [3117]	validation_0-mlogloss:1.88295
# [3118]	validation_0-mlogloss:1.88295
# [3119]	validation_0-mlogloss:1.88295
# [3120]	validation_0-mlogloss:1.88294
# [3121]	validation_0-mlogloss:1.88294
# [3122]	validation_0-mlogloss:1.88294
# [3123]	validation_0-mlogloss:1.88294
# [3124]	validation_0-mlogloss:1.88294
# [3125]	validation_0-mlogloss:1.88293
# [3126]	validation_0-mlogloss:1.88293
# [3127]	validation_0-mlogloss:1.88293
# [3128]	validation_0-mlogloss:1.88293
# [3129]	validation_0-mlogloss:1.88293
# [3130]	validation_0-mlogloss:1.88293
# [3131]	validation_0-mlogloss:1.88293
# [3132]	validation_0-mlogloss:1.88293
# [3133]	validation_0-mlogloss:1.88292
# [3134]	validation_0-mlogloss:1.88292
# [3135]	validation_0-mlogloss:1.88292
# [3136]	validation_0-mlogloss:1.88292
# [3137]	validation_0-mlogloss:1.88292
# [3138]	validation_0-mlogloss:1.88292
# [3139]	validation_0-mlogloss:1.88291
# [3140]	validation_0-mlogloss:1.88291
# [3141]	validation_0-mlogloss:1.88291
# [3142]	validation_0-mlogloss:1.88291
# [3143]	validation_0-mlogloss:1.88291
# [3144]	validation_0-mlogloss:1.88291
# [3145]	validation_0-mlogloss:1.88291
# [3146]	validation_0-mlogloss:1.88291
# [3147]	validation_0-mlogloss:1.88291
# [3148]	validation_0-mlogloss:1.88291
# [3149]	validation_0-mlogloss:1.88290
# [3150]	validation_0-mlogloss:1.88290
# [3151]	validation_0-mlogloss:1.88290
# [3152]	validation_0-mlogloss:1.88289
# [3153]	validation_0-mlogloss:1.88289
# [3154]	validation_0-mlogloss:1.88289
# [3155]	validation_0-mlogloss:1.88289
# [3156]	validation_0-mlogloss:1.88289
# [3157]	validation_0-mlogloss:1.88289
# [3158]	validation_0-mlogloss:1.88288
# [3159]	validation_0-mlogloss:1.88288
# [3160]	validation_0-mlogloss:1.88287
# [3161]	validation_0-mlogloss:1.88287
# [3162]	validation_0-mlogloss:1.88287
# [3163]	validation_0-mlogloss:1.88286
# [3164]	validation_0-mlogloss:1.88286
# [3165]	validation_0-mlogloss:1.88286
# [3166]	validation_0-mlogloss:1.88286
# [3167]	validation_0-mlogloss:1.88285
# [3168]	validation_0-mlogloss:1.88285
# [3169]	validation_0-mlogloss:1.88284
# [3170]	validation_0-mlogloss:1.88285
# [3171]	validation_0-mlogloss:1.88284
# [3172]	validation_0-mlogloss:1.88284
# [3173]	validation_0-mlogloss:1.88284
# [3174]	validation_0-mlogloss:1.88284
# [3175]	validation_0-mlogloss:1.88284
# [3176]	validation_0-mlogloss:1.88283
# [3177]	validation_0-mlogloss:1.88283
# [3178]	validation_0-mlogloss:1.88283
# [3179]	validation_0-mlogloss:1.88283
# [3180]	validation_0-mlogloss:1.88283
# [3181]	validation_0-mlogloss:1.88283
# [3182]	validation_0-mlogloss:1.88283
# [3183]	validation_0-mlogloss:1.88283
# [3184]	validation_0-mlogloss:1.88283
# [3185]	validation_0-mlogloss:1.88283
# [3186]	validation_0-mlogloss:1.88282
# [3187]	validation_0-mlogloss:1.88282
# [3188]	validation_0-mlogloss:1.88282
# [3189]	validation_0-mlogloss:1.88281
# [3190]	validation_0-mlogloss:1.88281
# [3191]	validation_0-mlogloss:1.88281
# [3192]	validation_0-mlogloss:1.88281
# [3193]	validation_0-mlogloss:1.88281
# [3194]	validation_0-mlogloss:1.88281
# [3195]	validation_0-mlogloss:1.88281
# [3196]	validation_0-mlogloss:1.88281
# [3197]	validation_0-mlogloss:1.88280
# [3198]	validation_0-mlogloss:1.88280
# [3199]	validation_0-mlogloss:1.88280
# [3200]	validation_0-mlogloss:1.88280
# [3201]	validation_0-mlogloss:1.88279
# [3202]	validation_0-mlogloss:1.88279
# [3203]	validation_0-mlogloss:1.88279
# [3204]	validation_0-mlogloss:1.88279
# [3205]	validation_0-mlogloss:1.88278
# [3206]	validation_0-mlogloss:1.88278
# [3207]	validation_0-mlogloss:1.88278
# [3208]	validation_0-mlogloss:1.88278
# [3209]	validation_0-mlogloss:1.88277
# [3210]	validation_0-mlogloss:1.88277
# [3211]	validation_0-mlogloss:1.88277
# [3212]	validation_0-mlogloss:1.88277
# [3213]	validation_0-mlogloss:1.88277
# [3214]	validation_0-mlogloss:1.88277
# [3215]	validation_0-mlogloss:1.88276
# [3216]	validation_0-mlogloss:1.88276
# [3217]	validation_0-mlogloss:1.88276
# [3218]	validation_0-mlogloss:1.88276
# [3219]	validation_0-mlogloss:1.88275
# [3220]	validation_0-mlogloss:1.88275
# [3221]	validation_0-mlogloss:1.88275
# [3222]	validation_0-mlogloss:1.88275
# [3223]	validation_0-mlogloss:1.88275
# [3224]	validation_0-mlogloss:1.88274
# [3225]	validation_0-mlogloss:1.88274
# [3226]	validation_0-mlogloss:1.88275
# [3227]	validation_0-mlogloss:1.88275
# [3228]	validation_0-mlogloss:1.88275
# [3229]	validation_0-mlogloss:1.88274
# [3230]	validation_0-mlogloss:1.88274
# [3231]	validation_0-mlogloss:1.88274
# [3232]	validation_0-mlogloss:1.88274
# [3233]	validation_0-mlogloss:1.88273
# [3234]	validation_0-mlogloss:1.88273
# [3235]	validation_0-mlogloss:1.88273
# [3236]	validation_0-mlogloss:1.88273
# [3237]	validation_0-mlogloss:1.88273
# [3238]	validation_0-mlogloss:1.88273
# [3239]	validation_0-mlogloss:1.88273
# [3240]	validation_0-mlogloss:1.88273
# [3241]	validation_0-mlogloss:1.88273
# [3242]	validation_0-mlogloss:1.88272
# [3243]	validation_0-mlogloss:1.88272
# [3244]	validation_0-mlogloss:1.88272
# [3245]	validation_0-mlogloss:1.88272
# [3246]	validation_0-mlogloss:1.88272
# [3247]	validation_0-mlogloss:1.88272
# [3248]	validation_0-mlogloss:1.88272
# [3249]	validation_0-mlogloss:1.88271
# [3250]	validation_0-mlogloss:1.88272
# [3251]	validation_0-mlogloss:1.88271
# [3252]	validation_0-mlogloss:1.88271
# [3253]	validation_0-mlogloss:1.88270
# [3254]	validation_0-mlogloss:1.88269
# [3255]	validation_0-mlogloss:1.88269
# [3256]	validation_0-mlogloss:1.88269
# [3257]	validation_0-mlogloss:1.88269
# [3258]	validation_0-mlogloss:1.88269
# [3259]	validation_0-mlogloss:1.88268
# [3260]	validation_0-mlogloss:1.88268
# [3261]	validation_0-mlogloss:1.88267
# [3262]	validation_0-mlogloss:1.88267
# [3263]	validation_0-mlogloss:1.88267
# [3264]	validation_0-mlogloss:1.88267
# [3265]	validation_0-mlogloss:1.88267
# [3266]	validation_0-mlogloss:1.88266
# [3267]	validation_0-mlogloss:1.88266
# [3268]	validation_0-mlogloss:1.88266
# [3269]	validation_0-mlogloss:1.88266
# [3270]	validation_0-mlogloss:1.88265
# [3271]	validation_0-mlogloss:1.88265
# [3272]	validation_0-mlogloss:1.88265
# [3273]	validation_0-mlogloss:1.88265
# [3274]	validation_0-mlogloss:1.88265
# [3275]	validation_0-mlogloss:1.88264
# [3276]	validation_0-mlogloss:1.88264
# [3277]	validation_0-mlogloss:1.88264
# [3278]	validation_0-mlogloss:1.88264
# [3279]	validation_0-mlogloss:1.88264
# [3280]	validation_0-mlogloss:1.88264
# [3281]	validation_0-mlogloss:1.88263
# [3282]	validation_0-mlogloss:1.88263
# [3283]	validation_0-mlogloss:1.88263
# [3284]	validation_0-mlogloss:1.88263
# [3285]	validation_0-mlogloss:1.88263
# [3286]	validation_0-mlogloss:1.88262
# [3287]	validation_0-mlogloss:1.88262
# [3288]	validation_0-mlogloss:1.88262
# [3289]	validation_0-mlogloss:1.88262
# [3290]	validation_0-mlogloss:1.88262
# [3291]	validation_0-mlogloss:1.88262
# [3292]	validation_0-mlogloss:1.88261
# [3293]	validation_0-mlogloss:1.88262
# [3294]	validation_0-mlogloss:1.88261
# [3295]	validation_0-mlogloss:1.88262
# [3296]	validation_0-mlogloss:1.88261
# [3297]	validation_0-mlogloss:1.88261
# [3298]	validation_0-mlogloss:1.88261
# [3299]	validation_0-mlogloss:1.88261
# [3300]	validation_0-mlogloss:1.88261
# [3301]	validation_0-mlogloss:1.88260
# [3302]	validation_0-mlogloss:1.88260
# [3303]	validation_0-mlogloss:1.88260
# [3304]	validation_0-mlogloss:1.88260
# [3305]	validation_0-mlogloss:1.88260
# [3306]	validation_0-mlogloss:1.88259
# [3307]	validation_0-mlogloss:1.88259
# [3308]	validation_0-mlogloss:1.88259
# [3309]	validation_0-mlogloss:1.88259
# [3310]	validation_0-mlogloss:1.88258
# [3311]	validation_0-mlogloss:1.88258
# [3312]	validation_0-mlogloss:1.88258
# [3313]	validation_0-mlogloss:1.88258
# [3314]	validation_0-mlogloss:1.88257
# [3315]	validation_0-mlogloss:1.88257
# [3316]	validation_0-mlogloss:1.88257
# [3317]	validation_0-mlogloss:1.88257
# [3318]	validation_0-mlogloss:1.88257
# [3319]	validation_0-mlogloss:1.88257
# [3320]	validation_0-mlogloss:1.88257
# [3321]	validation_0-mlogloss:1.88256
# [3322]	validation_0-mlogloss:1.88256
# [3323]	validation_0-mlogloss:1.88256
# [3324]	validation_0-mlogloss:1.88256
# [3325]	validation_0-mlogloss:1.88256
# [3326]	validation_0-mlogloss:1.88256
# [3327]	validation_0-mlogloss:1.88255
# [3328]	validation_0-mlogloss:1.88255
# [3329]	validation_0-mlogloss:1.88255
# [3330]	validation_0-mlogloss:1.88255
# [3331]	validation_0-mlogloss:1.88255
# [3332]	validation_0-mlogloss:1.88254
# [3333]	validation_0-mlogloss:1.88254
# [3334]	validation_0-mlogloss:1.88254
# [3335]	validation_0-mlogloss:1.88254
# [3336]	validation_0-mlogloss:1.88254
# [3337]	validation_0-mlogloss:1.88254
# [3338]	validation_0-mlogloss:1.88253
# [3339]	validation_0-mlogloss:1.88253
# [3340]	validation_0-mlogloss:1.88253
# [3341]	validation_0-mlogloss:1.88253
# [3342]	validation_0-mlogloss:1.88253
# [3343]	validation_0-mlogloss:1.88252
# [3344]	validation_0-mlogloss:1.88252
# [3345]	validation_0-mlogloss:1.88252
# [3346]	validation_0-mlogloss:1.88252
# [3347]	validation_0-mlogloss:1.88252
# [3348]	validation_0-mlogloss:1.88252
# [3349]	validation_0-mlogloss:1.88252
# [3350]	validation_0-mlogloss:1.88252
# [3351]	validation_0-mlogloss:1.88252
# [3352]	validation_0-mlogloss:1.88252
# [3353]	validation_0-mlogloss:1.88251
# [3354]	validation_0-mlogloss:1.88251
# [3355]	validation_0-mlogloss:1.88251
# [3356]	validation_0-mlogloss:1.88251
# [3357]	validation_0-mlogloss:1.88251
# [3358]	validation_0-mlogloss:1.88250
# [3359]	validation_0-mlogloss:1.88250
# [3360]	validation_0-mlogloss:1.88250
# [3361]	validation_0-mlogloss:1.88250
# [3362]	validation_0-mlogloss:1.88250
# [3363]	validation_0-mlogloss:1.88250
# [3364]	validation_0-mlogloss:1.88250
# [3365]	validation_0-mlogloss:1.88250
# [3366]	validation_0-mlogloss:1.88250
# [3367]	validation_0-mlogloss:1.88250
# [3368]	validation_0-mlogloss:1.88250
# [3369]	validation_0-mlogloss:1.88250
# [3370]	validation_0-mlogloss:1.88249
# [3371]	validation_0-mlogloss:1.88249
# [3372]	validation_0-mlogloss:1.88249
# score for fold 10 is : 0.3744470588235294
# ----------
# cv mean score : 0.3727256862745098
# oofs mean score : 0.3727256862745098
# ----------

# %%
test_probas = []
for key, value in test_preds_dict.items():
    test_probas.append(value)

# %%
preds = test_preds_dict['xgb_1']
preds.shape
# Out:
# (250000, 7)

# %%
# baseline_cols = ['Temparature', 'Humidity', 'Moisture', 'Soil Type', 'Crop Type',
#        'Nitrogen', 'Potassium', 'Phosphorous']

# %%
# model = xgb.XGBClassifier(random_state=seed, enable_categorical=True, tree_method='hist', device='cuda')
# # model = xgb.XGBClassifier(**params)
# model.fit(X_trial, y_full)

# %%
# from sklearn.model_selection import learning_curve

# train_sizes, train_scores_8, val_scores_8 = learning_curve(
#     model, X_new[baseline_cols], y_full, cv=5)
    
# train_sizes, train_scores_17, val_scores_17 = learning_curve(
#     model, X_new[cols], y_full, cv=5)

# # If 17-feature model shows larger gap between train/val scores,
# # it's likely overfitting

# %%
# import matplotlib.pyplot as plt
# plt.figure(figsize=(10, 6))

# # Calculate means and standard deviations
# train_mean_8 = np.mean(train_scores_8, axis=1)
# train_std_8 = np.std(train_scores_8, axis=1)
# val_mean_8 = np.mean(val_scores_8, axis=1)
# val_std_8 = np.std(val_scores_8, axis=1)

# train_mean_17 = np.mean(train_scores_17, axis=1)
# train_std_17 = np.std(train_scores_17, axis=1)
# val_mean_17 = np.mean(val_scores_17, axis=1)
# val_std_17 = np.std(val_scores_17, axis=1)

# # Plot 8-feature model
# plt.plot(train_sizes, train_mean_8, 'o-', color='blue', label='8-feature Train')
# plt.fill_between(train_sizes, train_mean_8 - train_std_8, train_mean_8 + train_std_8, alpha=0.1, color='blue')

# plt.plot(train_sizes, val_mean_8, 'o-', color='orange', label='8-feature Val')
# plt.fill_between(train_sizes, val_mean_8 - val_std_8, val_mean_8 + val_std_8, alpha=0.1, color='orange')

# # Plot 17-feature model
# plt.plot(train_sizes, train_mean_17, 'o--', color='green', label='17-feature Train')
# plt.fill_between(train_sizes, train_mean_17 - train_std_17, train_mean_17 + train_std_17, alpha=0.1, color='green')

# plt.plot(train_sizes, val_mean_17, 'o--', color='red', label='17-feature Val')
# plt.fill_between(train_sizes, val_mean_17 - val_std_17, val_mean_17 + val_std_17, alpha=0.1, color='red')

# plt.title('Learning Curves Comparison')
# plt.xlabel('Training Examples')
# plt.ylabel('MAP@3 Score')
# plt.legend(loc='best')
# plt.grid()
# plt.show()

# %%
# preds = model.predict_proba(test_new)

# %%
# preds.shape

# %%
top3_indices = np.argsort(-preds, axis=1)[:, :3] 
top3_labels = [[rev_class_mapping[idx] for idx in row] for row in top3_indices]
formatted_predictions = [' '.join(preds) for preds in top3_labels]

sample_sub['Fertilizer Name'] = formatted_predictions
sample_sub.to_csv('submission.csv', index=False)

# %%
top3_indices
# Out:
# array([[1, 4, 5],
#        [2, 6, 3],
#        [4, 6, 3],
#        ...,
#        [5, 1, 6],
#        [1, 3, 2],
#        [0, 4, 2]])

# %%
sample_sub
# Out:
#             id             Fertilizer Name
# 0       750000          10-26-26 20-20 DAP
# 1       750001         17-17-17 Urea 28-28
# 2       750002            20-20 Urea 28-28
# 3       750003  14-35-14 10-26-26 17-17-17
# 4       750004            Urea 20-20 28-28
# ...        ...                         ...
# 249995  999995         Urea 14-35-14 28-28
# 249996  999996     28-28 17-17-17 10-26-26
# 249997  999997           DAP 10-26-26 Urea
# 249998  999998     10-26-26 28-28 17-17-17
# 249999  999999     14-35-14 20-20 17-17-17
#
# [250000 rows x 2 columns]
